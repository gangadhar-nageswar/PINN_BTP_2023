# %% [markdown]
# # **Libraries and Dependencies**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import sys
sys.path.insert(0, '../Utilities/')

import torch
from collections import OrderedDict

from pyDOE2 import lhs
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
from scipy.interpolate import griddata
# from plotting import newfig, savefig
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.gridspec as gridspec
import time

np.random.seed(1234)

# %%
# CUDA support 
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# %% [markdown]
# # **Random Testing**

# %%
a = torch.tensor(np.ones(shape=(3,1)), requires_grad=True).float().to(device)
b = torch.tensor(np.zeros(shape=(3,1)), requires_grad=True).float().to(device)

# %%
print((1-3*a)/2)
# Out:
# tensor([[-1.],
#         [-1.],
#         [-1.]], device='cuda:0', grad_fn=<DivBackward0>)

# %% [markdown]
# # **Data Generation**

# %%
# for the funciton
x0, x1 = 0, 1
y0, y1 = 0, 1
nx = 255
nt = 255

x = np.arange(nx+1)/nx
t = np.arange(nt+1)/nt
usol = np.zeros(shape=(nx+1, nt+1))

for i in range(nx+1):
    for j in range(nt+1):
        usol[i][j] = np.exp(-x[i]) * (x[i] + t[j]**3)

x = np.expand_dims(x, axis=0).transpose()
t = np.expand_dims(t, axis=0).transpose()

data = {"x": x, "t": t, "usol": usol}
scipy.io.savemat("test_data.mat", data)

# %% [markdown]
# # **Physics-informed Neural Networks**

# %%
# the deep neural network
class DNN(torch.nn.Module):
    def __init__(self, layers):
        super(DNN, self).__init__()
        
        # parameters
        self.depth = len(layers) - 1
        
        # set up layer order dict
        self.activation = torch.nn.Tanh
        self.activation_last_layer = torch.nn.Linear
        
        layer_list = list()
        for i in range(self.depth - 1): 
            layer = torch.nn.Linear(layers[i], layers[i+1])
            torch.nn.init.xavier_normal_(layer.weight.data, gain=1.0)
            torch.nn.init.zeros_(layer.bias.data)

            layer_list.append(
                ('layer_%d' % i, layer)
            )
            layer_list.append(('activation_%d' % i, self.activation()))
            # layer_list.append(('dropout_%d'%i, torch.nn.Dropout(0.005)))

            # layer_list.append(('normalisation_%d' % i, torch.nn.BatchNorm1d(layers[i+1])))
            # layer_list.append(('normalisation_%d' % i, torch.nn.layerNorm(layers[i+1])))

        layer_list.append(
            ('layer_%d' % (self.depth - 1), torch.nn.Linear(layers[-2], layers[-1]))
        )
        layerDict = OrderedDict(layer_list)
        
        # deploy layers
        self.layers = torch.nn.Sequential(layerDict)
        
    def forward(self, x):
        out = self.layers(x)
        return out

# %%
# the physics-guided neural network
class PhysicsInformedNN():
    def __init__(self, t_f, X_u, U_u, P_u, layers, lb, ub, X, U, P, temperature):
        
        # boundary conditions
        self.lb = torch.tensor(lb).float().to(device)
        self.ub = torch.tensor(ub).float().to(device)
        
        self.num_u = X_u.shape[0]

        # data
        self.x_u = torch.tensor(X_u, requires_grad=True).float().to(device)
        self.u_u = torch.tensor(U_u, requires_grad=True).float().to(device)
        self.p_u = torch.tensor(P_u, requires_grad=True).float().to(device)

        self.t_f = torch.tensor(t_f, requires_grad=True).float().to(device)

        # # grid points
        self.num_t = 100
        self.build_grid()

        self.layers = layers
        
        # deep neural networks
        self.dnn = DNN(layers).to(device)
        
        # optimizers: using the same settings
        self.optimizer = torch.optim.LBFGS(
            self.dnn.parameters(), 
            lr=1.0, 
            max_iter=20, 
            max_eval=20, 
            history_size=50,
            tolerance_grad=1e-5, 
            tolerance_change=1.0 * np.finfo(float).eps,
            line_search_fn="strong_wolfe"       # can be "strong_wolfe"
        )

        self.num_epochs = 400
        
        self.iter = 0
        self.temperature = temperature
        self.set_adaptive_col_params()

        #random seeds
        self.lhs_rs = 0
        torch.manual_seed(0)
        np.random.seed(1234)

    def build_grid(self):
        grid_t = np.zeros(shape=(1, self.num_t))
        grid_t = self.lb + ((self.ub - self.lb)/(self.num_t - 1))*np.arange(self.num_t)

        self.grid_t = torch.tensor(grid_t, requires_grad=True).float().to(device)      

    def set_adaptive_col_params(self):
        self.proxy = "adapt-r"
        self.gamma = 0.0
        self.T = 50
        self.temperature = self.temperature
        self.e = 2

    def net_g(self, x, t):
        X = torch.cat([x, t], dim=1)

        # X = torch.tensor([x, t], requires_grad=True).float().to(device)
        # X = torch.tensor([-0.5, 0.5], requires_grad=True).float().to(device)

        g = self.dnn(X)
        return g

    def net_u(self, x, t):
        
        xt_shape = x.shape[0]
        tensor0 = torch.tensor(np.zeros(shape=(xt_shape,1)), requires_grad=True).float().to(device)
        tensor1 = torch.tensor(np.ones(shape=(xt_shape,1)), requires_grad=True).float().to(device)
        
        g = self.net_g(x, t)
        g_x_0 = self.net_g(x, tensor0)
        g_n1_0 = self.net_g(-tensor1, tensor0)
        g_n1_t = self.net_g(-tensor1, t)
        g_1_0 = self.net_g(tensor1, tensor0)
        g_1_t = self.net_g(tensor1, t)
        
        u = g + (-torch.sin(np.pi*x) - g_x_0) + (g_n1_0 - g_n1_t)*(1-x)/2 + (g_1_0 - g_1_t)*(1+x)/2

        return u

    def net_f(self, x, t):
        """ The pytorch autograd version of calculating residual """
        u = self.net_u(x, t)
        
        u_t = torch.autograd.grad(
            u, t, 
            grad_outputs=torch.ones_like(u),
            retain_graph=True,
            create_graph=True,
            allow_unused=True
        )[0]

        u_x = torch.autograd.grad(
            u, x, 
            grad_outputs=torch.ones_like(u),
            retain_graph=True,
            create_graph=True,
            allow_unused=True
        )[0]

        u_xx = torch.autograd.grad(
            u_x, x, 
            grad_outputs=torch.ones_like(u_x),
            retain_graph=True,
            create_graph=True,
            allow_unused=True
        )[0]

        u_tt = torch.autograd.grad(
            u_t, t, 
            grad_outputs=torch.ones_like(u_t),
            retain_graph=True,
            create_graph=True,
            allow_unused=True
        )[0]
        
        f = u_t + u * u_x - self.nu * u_xx

        return f
    
    def grad_value(self, x, t):
        u = self.net_u(x, t)
        
        u_t = torch.autograd.grad(
            u, t, 
            grad_outputs=torch.ones_like(u),
            retain_graph=True,
            create_graph=True,
            allow_unused=True
        )[0]

        u_x = torch.autograd.grad(
            u, x, 
            grad_outputs=torch.ones_like(u),
            retain_graph=True,
            create_graph=True,
            allow_unused=True
        )[0]
        
        grad_tensor = torch.sqrt(torch.square(u_x) + torch.square(u_t))
        
        return grad_tensor

    def proxy_func(self):
        prob = np.zeros(shape=(self.num_x, self.num_t))

        start = time.time()
        
        if self.proxy == 'adapt-r':
            prob_proxy = self.net_f(self.grid_x, self.grid_t)
        elif self.proxy == 'adapt-g':
            prob_proxy = self.grad_value(self.grid_x, self.grid_t)

        prob_proxy = abs(prob_proxy)
        max_value = prob_proxy.max()
        print('iter: {} | max value in prob: {}'.format(self.iter, max_value))
        prob_proxy = torch.sub(prob_proxy, max_value)
        prob_proxy = torch.exp(prob_proxy/self.temperature)
        prob = np.transpose(np.reshape(prob_proxy.cpu().detach().numpy(), (self.num_t, self.num_x)))

        return prob/prob.sum()

    def sample_uniform(self, size):
        
        x_f_train1 = self.lb[0].item() + (self.ub[0].item() - self.lb[0].item())*lhs(1, size, random_state=self.lhs_rs)
        t_f_train1 = self.lb[1].item() + (self.ub[1].item() - self.lb[1].item())*lhs(1, size)

        return x_f_train1, t_f_train1
    
    def sample_proxy(self, size):
        
        # normalise the array again
        self.prob /= self.prob.sum()
        flat = self.prob.flatten()

        x_f_train2 = np.zeros(shape=(size, 1))
        t_f_train2 = np.zeros(shape=(size, 1))

        for s in range(size):
            sample_index = np.random.choice(a=flat.size, p=flat)
            index = np.unravel_index(sample_index, self.prob.shape)

            x = self.lb[0] + (self.ub[0] - self.lb[0]) * index[0] / (self.num_x)
            t = self.lb[1] + (self.ub[1] - self.lb[1]) * index[1] / (self.num_t)

            x_f_train2[s][0] = x
            t_f_train2[s][0] = t

        return x_f_train2, t_f_train2

    def loss_func_old(self):

        global train_error
        
        self.optimizer.zero_grad()
        
        u_pred = self.net_u(self.x_u, self.t_u)
        f_pred = self.net_f(self.x_f, self.t_f)

        self.loss_u = torch.mean((self.u - u_pred) ** 2)
        self.loss_f = torch.mean(f_pred ** 2)
        
        loss = self.loss_u + self.loss_f
        
        loss.backward()

        self.iter += 1
        # if self.iter % 100 == 0:
        print(
            'Iter %d, Loss: %.5e, Loss_u: %.5e, Loss_f: %.5e' % (self.iter, loss.item(), self.loss_u.item(), self.loss_f.item())
        )
        
        train_error.append(loss.item())

        return loss
    
    def loss_func_ocp(self):

        global train_error
        
        self.optimizer.zero_grad()
        f_pred = self.net_f(self.t_f)
        
        self.loss_f = torch.mean(f_pred ** 2)
        loss = self.loss_f

        loss.backward()

        self.iter += 1
        # if self.iter % 100 == 0:
        print(
            'Iter %d, Loss_f: %.5e' % (self.iter, self.loss_f.item())
        )
        
        train_error.append(loss.item())

        return loss
    
    def adaptive_train(self):
        # set the model training mode "on"
        self.dnn.train()

        self.prob = np.ones(shape=(self.num_x, self.num_t)) / (self.num_x * self.num_t)

        for epoch_index in range(self.num_epochs):
            print(f"epoch: {epoch_index} | iter: {self.iter}")
            print(f"calculating probablities")
            new_prob = self.proxy_func()
            self.prob = new_prob + self.gamma * self.prob
            self.prob /= self.prob.sum()

            if epoch_index % self.e == 0:

                # cosine annealing
                self.Tc = epoch_index % self.T
                self.eta = 1/2 * (1 + np.cos(np.pi * self.Tc/self.T))

                x_f1, t_f1 = self.sample_uniform(int(self.eta * self.num_f))
                x_f2, t_f2 = self.sample_proxy(int((1-self.eta)*self.num_f))

                self.x_f = np.concatenate((x_f1, x_f2), axis=0)
                self.t_f = np.concatenate((t_f1, t_f2), axis=0)

                self.x_f = torch.tensor(self.x_f, requires_grad=True).float().to(device)
                self.t_f = torch.tensor(self.t_f, requires_grad=True).float().to(device)

                # # gibbs annealing
                # if epoch_index > int(0.2*self.num_epochs) and self.temperature > 20:
                #   self.temperature = 0.99 * self.temperature

                # x_f2, t_f2 = self.sample_proxy(int((self.num_f)))

                # self.x_f = torch.tensor(x_f2, requires_grad=True).float().to(device)
                # self.t_f = torch.tensor(t_f2, requires_grad=True).float().to(device)

            # Backward and optimize
            self.optimizer.step(self.loss_func)
            
            # # get a test error
            # global test_error
            # u_pred, f_pred = model.predict(X_star)

            # error_u = np.linalg.norm(u_star-u_pred,2)/np.linalg.norm(u_star,2)
            # test_error.append(error_u)
        
        return None
    
    def vanilla_train(self):
        # set the model training mode "on"
        self.dnn.train()

        for epoch_index in range(self.num_epochs):
            self.optimizer.step(self.loss_func_ocp)
    
            
    def predict(self, X):
        x = torch.tensor(X[:, 0:1], requires_grad=True).float().to(device)
        t = torch.tensor(X[:, 1:2], requires_grad=True).float().to(device)

        self.dnn.eval()
        u = self.net_u(x, t)
        f = self.net_f(x, t)
        u = u.detach().cpu().numpy()
        f = f.detach().cpu().numpy()
        return u, f

# %% [markdown]
# # **Configurations**

# %%
############################ Hypersensitive Problem data loading #########################

noise = 0.0

train_error = []
test_error = []

N_u = 10
N_f = 100
n_neurs = 100
layers = [1, n_neurs, 2]

data = scipy.io.loadmat('/content/drive/MyDrive/SEM - 7/BTP/Phase-2/data/hypersensitive_data.mat')

t_f = np.arange(N_f)

t = data['t'].flatten()[:,None]
x = data['x_data'].flatten()[:,None]
u = data['u_data'].flatten()[:, None]
p = data['p_data'].flatten()[:, None]

print("type of t: {} || shape: {}".format(type(t), t.shape))
print("type of x: {} || shape: {}".format(type(x), x.shape))
print("type of u: {} || shape: {}".format(type(u), u.shape))
print("type of p: {} || shape: {}".format(type(p), p.shape))

# supervised learning
idx = np.random.choice(t.shape[0], N_u, replace=False)

x_train = x[idx, :]
u_train = u[idx, :]
p_train = p[idx, :]

# Exact = np.real(data['usol']).T

# X, T = np.meshgrid(x,t)
# print("type of X: {} || shape: {}".format(type(X), X.shape))
# print("type of T: {} || shape: {}".format(type(T), T.shape))

# X_star = np.hstack((X.flatten()[:,None], T.flatten()[:,None]))
# print("type of X_star: {} || shape: {}".format(type(X_star), X_star.shape))

# u_star = Exact.flatten()[:,None]              

# # Doman bounds
# lb = X_star.min(0)
# ub = X_star.max(0)
# mu = X_star.mean()
# var = X_star.var()    

# xx1 = np.hstack((X[0:1,:].T, T[0:1,:].T))
# uu1 = Exact[0:1,:].T
# xx2 = np.hstack((X[:,0:1], T[:,0:1]))
# uu2 = Exact[:,0:1]
# xx3 = np.hstack((X[:,-1:], T[:,-1:]))
# uu3 = Exact[:,-1:]

# X_u_train = np.vstack([xx1, xx2, xx3])

# X_f_train = lb + (ub-lb)*lhs(2, N_f)
# # X_f_train = (lhs(2, N_f) - mu) / var
# # X_f_train = np.vstack((X_f_train, X_u_train))

# u_train = np.vstack([uu1, uu2, uu3])

# idx = np.random.choice(X_u_train.shape[0], N_u, replace=False)
# X_u_train = X_u_train[idx, :]
# u_train = u_train[idx,:]

# #u_pred, f_pred = model.predict(X_star)

# #error_u = np.linalg.norm(u_star-u_pred,2)/np.linalg.norm(u_star,2)
# #print('Error u: %e' % (error_u))                     

# #U_pred = griddata(X_star, u_pred.flatten(), (X, T), method='cubic')
# #Error = np.abs(Exact - U_pred)
# Out:
# type of t: <class 'numpy.ndarray'> || shape: (10001, 1)
# type of x: <class 'numpy.ndarray'> || shape: (10001, 1)
# type of u: <class 'numpy.ndarray'> || shape: (10001, 1)
# type of p: <class 'numpy.ndarray'> || shape: (10001, 1)

# %% [markdown]
# # **Training**

# %%
model = PhysicsInformedNN(t_f, x_train, u_train, p_train, layers, lb=0, ub=1, x, u, p, temperature=50000)

# %%
# %%time

model.vanilla_train()
# Out:
# Iter 1, Loss_f: 1.26336e+00
# Iter 2, Loss_f: 1.25172e+00
# Iter 3, Loss_f: 1.23379e+00
# Iter 4, Loss_f: 1.22817e+00
# Iter 5, Loss_f: 1.21860e+00
# Iter 6, Loss_f: 1.09299e+00
# Iter 7, Loss_f: 1.14757e+00
# Iter 8, Loss_f: 1.06084e+00
# Iter 9, Loss_f: 2.08759e+00
# Iter 10, Loss_f: 1.05481e+00
# Iter 11, Loss_f: 9.54995e-01
# Iter 12, Loss_f: 1.65134e+00
# Iter 13, Loss_f: 8.70939e-01
# Iter 14, Loss_f: 8.96570e-01
# Iter 15, Loss_f: 8.56436e-01
# Iter 16, Loss_f: 8.50943e-01
# Iter 17, Loss_f: 8.30616e-01
# Iter 18, Loss_f: 7.12170e-01
# Iter 19, Loss_f: 7.38889e-01
# Iter 20, Loss_f: 6.97731e-01
# Iter 21, Loss_f: 6.97731e-01
# Iter 22, Loss_f: 6.70526e-01
# Iter 23, Loss_f: 6.24974e-01
# Iter 24, Loss_f: 6.41561e-01
# Iter 25, Loss_f: 6.10151e-01
# Iter 26, Loss_f: 5.90569e-01
# Iter 27, Loss_f: 6.06354e-01
# Iter 28, Loss_f: 5.78352e-01
# Iter 29, Loss_f: 5.52638e-01
# Iter 30, Loss_f: 5.66266e+00
# Iter 31, Loss_f: 4.94750e-01
# Iter 32, Loss_f: 4.42372e-01
# Iter 33, Loss_f: 2.10662e+00
# Iter 34, Loss_f: 4.21329e-01
# Iter 35, Loss_f: 4.15273e-01
# Iter 36, Loss_f: 4.20325e-01
# Iter 37, Loss_f: 4.09496e-01
# Iter 38, Loss_f: 4.06915e-01
# Iter 39, Loss_f: 4.05561e-01
# Iter 40, Loss_f: 3.97842e-01
# Iter 41, Loss_f: 3.97842e-01
# Iter 42, Loss_f: 3.82182e-01
# Iter 43, Loss_f: 3.69916e-01
# Iter 44, Loss_f: 3.59038e-01
# Iter 45, Loss_f: 3.54288e-01
# Iter 46, Loss_f: 3.43972e-01
# Iter 47, Loss_f: 3.36127e-01
# Iter 48, Loss_f: 3.32074e-01
# Iter 49, Loss_f: 3.25285e-01
# Iter 50, Loss_f: 3.15029e-01
# Iter 51, Loss_f: 3.06586e-01
# Iter 52, Loss_f: 3.04919e-01
# Iter 53, Loss_f: 3.02000e-01
# Iter 54, Loss_f: 2.95237e-01
# Iter 55, Loss_f: 2.91064e-01
# Iter 56, Loss_f: 2.88720e-01
# Iter 57, Loss_f: 2.83774e-01
# Iter 58, Loss_f: 2.79124e-01
# Iter 59, Loss_f: 2.73673e-01
# Iter 60, Loss_f: 2.70053e-01
# Iter 61, Loss_f: 2.70053e-01
# Iter 62, Loss_f: 2.68082e-01
# Iter 63, Loss_f: 2.65801e-01
# Iter 64, Loss_f: 2.62001e-01
# Iter 65, Loss_f: 2.98507e-01
# Iter 66, Loss_f: 2.60873e-01
# Iter 67, Loss_f: 2.59201e-01
# Iter 68, Loss_f: 2.58799e-01
# Iter 69, Loss_f: 2.57380e-01
# Iter 70, Loss_f: 2.56275e-01
# Iter 71, Loss_f: 2.54970e-01
# Iter 72, Loss_f: 2.53379e-01
# Iter 73, Loss_f: 2.52242e-01
# Iter 74, Loss_f: 2.50967e-01
# Iter 75, Loss_f: 2.50032e-01
# Iter 76, Loss_f: 2.49519e-01
# Iter 77, Loss_f: 2.48333e-01
# Iter 78, Loss_f: 2.45673e-01
# Iter 79, Loss_f: 2.44944e-01
# Iter 80, Loss_f: 2.43089e-01
# Iter 81, Loss_f: 2.43089e-01
# Iter 82, Loss_f: 2.47846e-01
# Iter 83, Loss_f: 2.41915e-01
# Iter 84, Loss_f: 2.39698e-01
# Iter 85, Loss_f: 2.37509e-01
# Iter 86, Loss_f: 2.34556e-01
# Iter 87, Loss_f: 2.30862e-01
# Iter 88, Loss_f: 2.29711e-01
# Iter 89, Loss_f: 2.29363e-01
# Iter 90, Loss_f: 2.27750e-01
# Iter 91, Loss_f: 2.26668e-01
# Iter 92, Loss_f: 2.25768e-01
# Iter 93, Loss_f: 2.25407e-01
# Iter 94, Loss_f: 2.24683e-01
# Iter 95, Loss_f: 2.23254e-01
# Iter 96, Loss_f: 2.21396e-01
# Iter 97, Loss_f: 2.16460e-01
# Iter 98, Loss_f: 2.12429e-01
# Iter 99, Loss_f: 2.21025e-01
# Iter 100, Loss_f: 2.09713e-01
# Iter 101, Loss_f: 2.09713e-01
# Iter 102, Loss_f: 2.08871e-01
# Iter 103, Loss_f: 2.06614e-01
# Iter 104, Loss_f: 2.04629e-01
# Iter 105, Loss_f: 2.04766e-01
# Iter 106, Loss_f: 2.04293e-01
# Iter 107, Loss_f: 2.03726e-01
# Iter 108, Loss_f: 2.02923e-01
# Iter 109, Loss_f: 2.02392e-01
# Iter 110, Loss_f: 2.01833e-01
# Iter 111, Loss_f: 2.01381e-01
# Iter 112, Loss_f: 2.01667e-01
# Iter 113, Loss_f: 2.00915e-01
# Iter 114, Loss_f: 2.00558e-01
# Iter 115, Loss_f: 2.00201e-01
# Iter 116, Loss_f: 1.99887e-01
# Iter 117, Loss_f: 1.99139e-01
# Iter 118, Loss_f: 1.97502e-01
# Iter 119, Loss_f: 1.96780e-01
# Iter 120, Loss_f: 1.96018e-01
# Iter 121, Loss_f: 1.96018e-01
# Iter 122, Loss_f: 1.95345e-01
# Iter 123, Loss_f: 1.94903e-01
# Iter 124, Loss_f: 1.94403e-01
# Iter 125, Loss_f: 1.94179e-01
# Iter 126, Loss_f: 1.93935e-01
# Iter 127, Loss_f: 1.93699e-01
# Iter 128, Loss_f: 1.93213e-01
# Iter 129, Loss_f: 1.91846e-01
# Iter 130, Loss_f: 1.90398e-01
# Iter 131, Loss_f: 2.04839e-01
# Iter 132, Loss_f: 1.89285e-01
# Iter 133, Loss_f: 1.87344e-01
# Iter 134, Loss_f: 1.86442e-01
# Iter 135, Loss_f: 1.86132e-01
# Iter 136, Loss_f: 1.85481e-01
# Iter 137, Loss_f: 1.84505e-01
# Iter 138, Loss_f: 1.84174e-01
# Iter 139, Loss_f: 1.83528e-01
# Iter 140, Loss_f: 1.82713e-01
# Iter 141, Loss_f: 1.82713e-01
# Iter 142, Loss_f: 1.82343e-01
# Iter 143, Loss_f: 1.81172e-01
# Iter 144, Loss_f: 1.80442e-01
# Iter 145, Loss_f: 1.81899e-01
# Iter 146, Loss_f: 1.80019e-01
# Iter 147, Loss_f: 1.79382e-01
# Iter 148, Loss_f: 1.78439e-01
# Iter 149, Loss_f: 1.77618e-01
# Iter 150, Loss_f: 1.76649e-01
# Iter 151, Loss_f: 1.75867e-01
# Iter 152, Loss_f: 1.94153e-01
# Iter 153, Loss_f: 1.74384e-01
# Iter 154, Loss_f: 1.72759e-01
# Iter 155, Loss_f: 1.71724e-01
# Iter 156, Loss_f: 1.70812e-01
# Iter 157, Loss_f: 1.70152e-01
# Iter 158, Loss_f: 1.68923e-01
# Iter 159, Loss_f: 1.68381e-01
# Iter 160, Loss_f: 1.68297e-01
# Iter 161, Loss_f: 1.68297e-01
# Iter 162, Loss_f: 1.67985e-01
# Iter 163, Loss_f: 1.67930e-01
# Iter 164, Loss_f: 1.67831e-01
# Iter 165, Loss_f: 1.67633e-01
# Iter 166, Loss_f: 1.67540e-01
# Iter 167, Loss_f: 1.67455e-01
# Iter 168, Loss_f: 1.67322e-01
# Iter 169, Loss_f: 1.67132e-01
# Iter 170, Loss_f: 1.66677e-01
# Iter 171, Loss_f: 1.65846e-01
# Iter 172, Loss_f: 1.65331e-01
# Iter 173, Loss_f: 1.65007e-01
# Iter 174, Loss_f: 1.64818e-01
# Iter 175, Loss_f: 1.64592e-01
# Iter 176, Loss_f: 1.64497e-01
# Iter 177, Loss_f: 1.64431e-01
# Iter 178, Loss_f: 1.64369e-01
# Iter 179, Loss_f: 1.64245e-01
# Iter 180, Loss_f: 1.64100e-01
# Iter 181, Loss_f: 1.64100e-01
# Iter 182, Loss_f: 1.63824e-01
# Iter 183, Loss_f: 1.63390e-01
# Iter 184, Loss_f: 1.63344e-01
# Iter 185, Loss_f: 1.63075e-01
# Iter 186, Loss_f: 1.62586e-01
# Iter 187, Loss_f: 1.62101e-01
# Iter 188, Loss_f: 1.61694e-01
# Iter 189, Loss_f: 1.61546e-01
# Iter 190, Loss_f: 1.61386e-01
# Iter 191, Loss_f: 1.61275e-01
# Iter 192, Loss_f: 1.61111e-01
# Iter 193, Loss_f: 1.60855e-01
# Iter 194, Loss_f: 1.60660e-01
# Iter 195, Loss_f: 1.60541e-01
# Iter 196, Loss_f: 1.60234e-01
# Iter 197, Loss_f: 1.60036e-01
# Iter 198, Loss_f: 1.59827e-01
# Iter 199, Loss_f: 1.59284e-01
# Iter 200, Loss_f: 1.61578e-01
# Iter 201, Loss_f: 1.58797e-01
# Iter 202, Loss_f: 1.58797e-01
# Iter 203, Loss_f: 1.58050e-01
# Iter 204, Loss_f: 1.56331e-01
# Iter 205, Loss_f: 1.68754e-01
# Iter 206, Loss_f: 1.55255e-01
# Iter 207, Loss_f: 1.54166e-01
# Iter 208, Loss_f: 1.54151e-01
# Iter 209, Loss_f: 1.53486e-01
# Iter 210, Loss_f: 1.52259e-01
# Iter 211, Loss_f: 1.55074e-01
# Iter 212, Loss_f: 1.51999e-01
# Iter 213, Loss_f: 1.51743e-01
# Iter 214, Loss_f: 1.51477e-01
# Iter 215, Loss_f: 1.50964e-01
# Iter 216, Loss_f: 1.50451e-01
# Iter 217, Loss_f: 1.49584e-01
# Iter 218, Loss_f: 1.57908e-01
# Iter 219, Loss_f: 1.49213e-01
# Iter 220, Loss_f: 1.48089e-01
# Iter 221, Loss_f: 1.48442e-01
# Iter 222, Loss_f: 1.47462e-01
# Iter 223, Loss_f: 1.47462e-01
# Iter 224, Loss_f: 1.46873e-01
# Iter 225, Loss_f: 1.46365e-01
# Iter 226, Loss_f: 1.47184e-01
# Iter 227, Loss_f: 1.45794e-01
# Iter 228, Loss_f: 1.45736e-01
# Iter 229, Loss_f: 1.45566e-01
# Iter 230, Loss_f: 1.45119e-01
# Iter 231, Loss_f: 1.44550e-01
# Iter 232, Loss_f: 1.44346e-01
# Iter 233, Loss_f: 1.44120e-01
# Iter 234, Loss_f: 1.43287e-01
# Iter 235, Loss_f: 1.42923e-01
# Iter 236, Loss_f: 1.42502e-01
# Iter 237, Loss_f: 1.42397e-01
# Iter 238, Loss_f: 1.41801e-01
# Iter 239, Loss_f: 1.41434e-01
# Iter 240, Loss_f: 1.40861e-01
# Iter 241, Loss_f: 1.38298e-01
# Iter 242, Loss_f: 1.36978e-01
# Iter 243, Loss_f: 1.36978e-01
# Iter 244, Loss_f: 1.36920e-01
# Iter 245, Loss_f: 1.36298e-01
# Iter 246, Loss_f: 1.34889e-01
# Iter 247, Loss_f: 1.34256e-01
# Iter 248, Loss_f: 1.33862e-01
# Iter 249, Loss_f: 1.33705e-01
# Iter 250, Loss_f: 1.33492e-01
# Iter 251, Loss_f: 1.33351e-01
# Iter 252, Loss_f: 1.33262e-01
# Iter 253, Loss_f: 1.32987e-01
# Iter 254, Loss_f: 1.32782e-01
# Iter 255, Loss_f: 1.32663e-01
# Iter 256, Loss_f: 1.32524e-01
# Iter 257, Loss_f: 1.32364e-01
# Iter 258, Loss_f: 1.32175e-01
# Iter 259, Loss_f: 1.31995e-01
# Iter 260, Loss_f: 1.31921e-01
# Iter 261, Loss_f: 1.31794e-01
# Iter 262, Loss_f: 1.31735e-01
# Iter 263, Loss_f: 1.31735e-01
# Iter 264, Loss_f: 1.31660e-01
# Iter 265, Loss_f: 1.31465e-01
# Iter 266, Loss_f: 1.31187e-01
# Iter 267, Loss_f: 1.30727e-01
# Iter 268, Loss_f: 1.30350e-01
# Iter 269, Loss_f: 1.30853e-01
# Iter 270, Loss_f: 1.30270e-01
# Iter 271, Loss_f: 1.30102e-01
# Iter 272, Loss_f: 1.29998e-01
# Iter 273, Loss_f: 1.29440e-01
# Iter 274, Loss_f: 1.29079e-01
# Iter 275, Loss_f: 1.29707e-01
# Iter 276, Loss_f: 1.28892e-01
# Iter 277, Loss_f: 1.28729e-01
# Iter 278, Loss_f: 1.28657e-01
# Iter 279, Loss_f: 1.28561e-01
# Iter 280, Loss_f: 1.28459e-01
# Iter 281, Loss_f: 1.28258e-01
# Iter 282, Loss_f: 1.28001e-01
# Iter 283, Loss_f: 1.28001e-01
# Iter 284, Loss_f: 1.27781e-01
# Iter 285, Loss_f: 1.27447e-01
# Iter 286, Loss_f: 1.27266e-01
# Iter 287, Loss_f: 1.27133e-01
# Iter 288, Loss_f: 1.26802e-01
# Iter 289, Loss_f: 1.26645e-01
# Iter 290, Loss_f: 1.26468e-01
# Iter 291, Loss_f: 1.26200e-01
# Iter 292, Loss_f: 1.26082e-01
# Iter 293, Loss_f: 1.25658e-01
# Iter 294, Loss_f: 1.25547e-01
# Iter 295, Loss_f: 1.25199e-01
# Iter 296, Loss_f: 1.25071e-01
# Iter 297, Loss_f: 1.25154e-01
# Iter 298, Loss_f: 1.24965e-01
# Iter 299, Loss_f: 1.24768e-01
# Iter 300, Loss_f: 1.24542e-01
# Iter 301, Loss_f: 1.24357e-01
# Iter 302, Loss_f: 1.24006e-01
# Iter 303, Loss_f: 1.24006e-01
# Iter 304, Loss_f: 1.23614e-01
# Iter 305, Loss_f: 1.23196e-01
# Iter 306, Loss_f: 1.22638e-01
# Iter 307, Loss_f: 1.22043e-01
# Iter 308, Loss_f: 1.21836e-01
# Iter 309, Loss_f: 1.21513e-01
# Iter 310, Loss_f: 1.21469e-01
# Iter 311, Loss_f: 1.21204e-01
# Iter 312, Loss_f: 1.20919e-01
# Iter 313, Loss_f: 1.20467e-01
# Iter 314, Loss_f: 1.20238e-01
# Iter 315, Loss_f: 1.20081e-01
# Iter 316, Loss_f: 1.19996e-01
# Iter 317, Loss_f: 1.19965e-01
# Iter 318, Loss_f: 1.19913e-01
# Iter 319, Loss_f: 1.19861e-01
# Iter 320, Loss_f: 1.19793e-01
# Iter 321, Loss_f: 1.19755e-01
# Iter 322, Loss_f: 1.19660e-01
# Iter 323, Loss_f: 1.19660e-01
# Iter 324, Loss_f: 1.19571e-01
# Iter 325, Loss_f: 1.19419e-01
# Iter 326, Loss_f: 1.19662e-01
# Iter 327, Loss_f: 1.19346e-01
# Iter 328, Loss_f: 1.19424e-01
# Iter 329, Loss_f: 1.19188e-01
# Iter 330, Loss_f: 1.18932e-01
# Iter 331, Loss_f: 1.18295e-01
# Iter 332, Loss_f: 1.19495e-01
# Iter 333, Loss_f: 1.18163e-01
# Iter 334, Loss_f: 1.17876e-01
# Iter 335, Loss_f: 1.17384e-01
# Iter 336, Loss_f: 1.16954e-01
# Iter 337, Loss_f: 1.16376e-01
# Iter 338, Loss_f: 1.22021e-01
# Iter 339, Loss_f: 1.16200e-01
# Iter 340, Loss_f: 1.15408e-01
# Iter 341, Loss_f: 1.15271e-01
# Iter 342, Loss_f: 1.14969e-01
# Iter 343, Loss_f: 1.14969e-01
# Iter 344, Loss_f: 1.14842e-01
# Iter 345, Loss_f: 1.14799e-01
# Iter 346, Loss_f: 1.14775e-01
# Iter 347, Loss_f: 1.14734e-01
# Iter 348, Loss_f: 1.14714e-01
# Iter 349, Loss_f: 1.14654e-01
# Iter 350, Loss_f: 1.14519e-01
# Iter 351, Loss_f: 1.14315e-01
# Iter 352, Loss_f: 1.13892e-01
# Iter 353, Loss_f: 1.13688e-01
# Iter 354, Loss_f: 1.15603e-01
# Iter 355, Loss_f: 1.13525e-01
# Iter 356, Loss_f: 1.13405e-01
# Iter 357, Loss_f: 1.13328e-01
# Iter 358, Loss_f: 1.13272e-01
# Iter 359, Loss_f: 1.13232e-01
# Iter 360, Loss_f: 1.13245e-01
# Iter 361, Loss_f: 1.13205e-01
# Iter 362, Loss_f: 1.13172e-01
# Iter 363, Loss_f: 1.13172e-01
# Iter 364, Loss_f: 1.13107e-01
# Iter 365, Loss_f: 1.13037e-01
# Iter 366, Loss_f: 1.12927e-01
# Iter 367, Loss_f: 1.12797e-01
# Iter 368, Loss_f: 3.12492e-01
# Iter 369, Loss_f: 1.14352e-01
# Iter 370, Loss_f: 1.12679e-01
# Iter 371, Loss_f: 1.12442e-01
# Iter 372, Loss_f: 1.12020e-01
# Iter 373, Loss_f: 1.11130e-01
# Iter 374, Loss_f: 1.10239e-01
# Iter 375, Loss_f: 1.09425e-01
# Iter 376, Loss_f: 1.11225e-01
# Iter 377, Loss_f: 1.09194e-01
# Iter 378, Loss_f: 1.08623e-01
# Iter 379, Loss_f: 1.08414e-01
# Iter 380, Loss_f: 1.08424e-01
# Iter 381, Loss_f: 1.08358e-01
# Iter 382, Loss_f: 1.08333e-01
# Iter 383, Loss_f: 1.08333e-01
# Iter 384, Loss_f: 1.08286e-01
# Iter 385, Loss_f: 1.08258e-01
# Iter 386, Loss_f: 1.08227e-01
# Iter 387, Loss_f: 1.08305e-01
# Iter 388, Loss_f: 1.08206e-01
# Iter 389, Loss_f: 1.08144e-01
# Iter 390, Loss_f: 1.08114e-01
# Iter 391, Loss_f: 1.08046e-01
# Iter 392, Loss_f: 1.08543e-01
# Iter 393, Loss_f: 1.08023e-01
# Iter 394, Loss_f: 1.07970e-01
# Iter 395, Loss_f: 1.07906e-01
# Iter 396, Loss_f: 1.07877e-01
# Iter 397, Loss_f: 1.07853e-01
# Iter 398, Loss_f: 1.07833e-01
# Iter 399, Loss_f: 1.07794e-01
# Iter 400, Loss_f: 1.08528e-01
# Iter 401, Loss_f: 1.07787e-01
# Iter 402, Loss_f: 1.07758e-01
# Iter 403, Loss_f: 1.07758e-01
# Iter 404, Loss_f: 1.07673e-01
# Iter 405, Loss_f: 1.07626e-01
# Iter 406, Loss_f: 1.07554e-01
# Iter 407, Loss_f: 1.07480e-01
# Iter 408, Loss_f: 1.07362e-01
# Iter 409, Loss_f: 1.07224e-01
# Iter 410, Loss_f: 1.07256e-01
# Iter 411, Loss_f: 1.07111e-01
# Iter 412, Loss_f: 1.06907e-01
# Iter 413, Loss_f: 1.06781e-01
# Iter 414, Loss_f: 1.06767e-01
# Iter 415, Loss_f: 1.06670e-01
# Iter 416, Loss_f: 1.06930e-01
# Iter 417, Loss_f: 1.06544e-01
# Iter 418, Loss_f: 1.06412e-01
# Iter 419, Loss_f: 1.07218e-01
# Iter 420, Loss_f: 1.06231e-01
# Iter 421, Loss_f: 1.06226e-01
# Iter 422, Loss_f: 1.06027e-01
# Iter 423, Loss_f: 1.06027e-01
# Iter 424, Loss_f: 1.05876e-01
# Iter 425, Loss_f: 1.05850e-01
# Iter 426, Loss_f: 1.05723e-01
# Iter 427, Loss_f: 1.05618e-01
# Iter 428, Loss_f: 1.05519e-01
# Iter 429, Loss_f: 1.05422e-01
# Iter 430, Loss_f: 1.05305e-01
# Iter 431, Loss_f: 1.05585e-01
# Iter 432, Loss_f: 1.05234e-01
# Iter 433, Loss_f: 1.05119e-01
# Iter 434, Loss_f: 1.04983e-01
# Iter 435, Loss_f: 1.05091e-01
# Iter 436, Loss_f: 1.04943e-01
# Iter 437, Loss_f: 1.04919e-01
# Iter 438, Loss_f: 1.04905e-01
# Iter 439, Loss_f: 1.05688e-01
# Iter 440, Loss_f: 1.04882e-01
# Iter 441, Loss_f: 1.04872e-01
# Iter 442, Loss_f: 1.04804e-01
# Iter 443, Loss_f: 1.04804e-01
# Iter 444, Loss_f: 1.04879e-01
# Iter 445, Loss_f: 1.04760e-01
# Iter 446, Loss_f: 1.04692e-01
# Iter 447, Loss_f: 1.04506e-01
# Iter 448, Loss_f: 1.04505e-01
# Iter 449, Loss_f: 1.04474e-01
# Iter 450, Loss_f: 1.04440e-01
# Iter 451, Loss_f: 1.04417e-01
# Iter 452, Loss_f: 1.04404e-01
# Iter 453, Loss_f: 1.04391e-01
# Iter 454, Loss_f: 1.04370e-01
# Iter 455, Loss_f: 1.04360e-01
# Iter 456, Loss_f: 1.04326e-01
# Iter 457, Loss_f: 1.04298e-01
# Iter 458, Loss_f: 1.04271e-01
# Iter 459, Loss_f: 1.04241e-01
# Iter 460, Loss_f: 1.04184e-01
# Iter 461, Loss_f: 1.04100e-01
# Iter 462, Loss_f: 1.06640e-01
# Iter 463, Loss_f: 1.04075e-01
# Iter 464, Loss_f: 1.04075e-01
# Iter 465, Loss_f: 1.04004e-01
# Iter 466, Loss_f: 1.03965e-01
# Iter 467, Loss_f: 1.03940e-01
# Iter 468, Loss_f: 1.03922e-01
# Iter 469, Loss_f: 1.03887e-01
# Iter 470, Loss_f: 1.03847e-01
# Iter 471, Loss_f: 1.03793e-01
# Iter 472, Loss_f: 1.03688e-01
# Iter 473, Loss_f: 1.03591e-01
# Iter 474, Loss_f: 1.03526e-01
# Iter 475, Loss_f: 1.03474e-01
# Iter 476, Loss_f: 1.03435e-01
# Iter 477, Loss_f: 1.03412e-01
# Iter 478, Loss_f: 1.03381e-01
# Iter 479, Loss_f: 1.03353e-01
# Iter 480, Loss_f: 1.03325e-01
# Iter 481, Loss_f: 1.03282e-01
# Iter 482, Loss_f: 1.03240e-01
# Iter 483, Loss_f: 1.03211e-01
# Iter 484, Loss_f: 1.03211e-01
# Iter 485, Loss_f: 1.03184e-01
# Iter 486, Loss_f: 1.03160e-01
# Iter 487, Loss_f: 1.03152e-01
# Iter 488, Loss_f: 1.03143e-01
# Iter 489, Loss_f: 1.03105e-01
# Iter 490, Loss_f: 1.03052e-01
# Iter 491, Loss_f: 1.02903e-01
# Iter 492, Loss_f: 1.09548e-01
# Iter 493, Loss_f: 1.02894e-01
# Iter 494, Loss_f: 1.02738e-01
# Iter 495, Loss_f: 1.02562e-01
# Iter 496, Loss_f: 1.02571e-01
# Iter 497, Loss_f: 1.02447e-01
# Iter 498, Loss_f: 1.02542e-01
# Iter 499, Loss_f: 1.02346e-01
# Iter 500, Loss_f: 1.02338e-01
# Iter 501, Loss_f: 1.02294e-01
# Iter 502, Loss_f: 1.02221e-01
# Iter 503, Loss_f: 1.02174e-01
# Iter 504, Loss_f: 1.02174e-01
# Iter 505, Loss_f: 1.02164e-01
# Iter 506, Loss_f: 1.02148e-01
# Iter 507, Loss_f: 1.02143e-01
# Iter 508, Loss_f: 1.02134e-01
# Iter 509, Loss_f: 1.02122e-01
# Iter 510, Loss_f: 1.02108e-01
# Iter 511, Loss_f: 1.02105e-01
# Iter 512, Loss_f: 1.02070e-01
# Iter 513, Loss_f: 1.02040e-01
# Iter 514, Loss_f: 1.02015e-01
# Iter 515, Loss_f: 1.01941e-01
# Iter 516, Loss_f: 1.01917e-01
# Iter 517, Loss_f: 1.01830e-01
# Iter 518, Loss_f: 1.01804e-01
# Iter 519, Loss_f: 1.01775e-01
# Iter 520, Loss_f: 1.01690e-01
# Iter 521, Loss_f: 1.01601e-01
# Iter 522, Loss_f: 1.01556e-01
# Iter 523, Loss_f: 1.01517e-01
# Iter 524, Loss_f: 1.01517e-01
# Iter 525, Loss_f: 1.01539e-01
# Iter 526, Loss_f: 1.01496e-01
# Iter 527, Loss_f: 1.01452e-01
# Iter 528, Loss_f: 1.01392e-01
# Iter 529, Loss_f: 1.01275e-01
# Iter 530, Loss_f: 1.01212e-01
# Iter 531, Loss_f: 1.01048e-01
# Iter 532, Loss_f: 1.01311e-01
# Iter 533, Loss_f: 1.00934e-01
# Iter 534, Loss_f: 1.02658e-01
# Iter 535, Loss_f: 1.00851e-01
# Iter 536, Loss_f: 1.00833e-01
# Iter 537, Loss_f: 1.00706e-01
# Iter 538, Loss_f: 1.00592e-01
# Iter 539, Loss_f: 1.00390e-01
# Iter 540, Loss_f: 1.00259e-01
# Iter 541, Loss_f: 1.01855e-01
# Iter 542, Loss_f: 1.00004e-01
# Iter 543, Loss_f: 9.97497e-02
# Iter 544, Loss_f: 9.97497e-02
# Iter 545, Loss_f: 1.00070e-01
# Iter 546, Loss_f: 9.96844e-02
# Iter 547, Loss_f: 9.98023e-02
# Iter 548, Loss_f: 9.95904e-02
# Iter 549, Loss_f: 9.95507e-02
# Iter 550, Loss_f: 9.94906e-02
# Iter 551, Loss_f: 9.94424e-02
# Iter 552, Loss_f: 9.93962e-02
# Iter 553, Loss_f: 9.96588e-02
# Iter 554, Loss_f: 9.93622e-02
# Iter 555, Loss_f: 9.92444e-02
# Iter 556, Loss_f: 9.91696e-02
# Iter 557, Loss_f: 9.91098e-02
# Iter 558, Loss_f: 9.90752e-02
# Iter 559, Loss_f: 9.90930e-02
# Iter 560, Loss_f: 9.90485e-02
# Iter 561, Loss_f: 9.90204e-02
# Iter 562, Loss_f: 9.90102e-02
# Iter 563, Loss_f: 9.89896e-02
# Iter 564, Loss_f: 9.89896e-02
# Iter 565, Loss_f: 9.89297e-02
# Iter 566, Loss_f: 9.88721e-02
# Iter 567, Loss_f: 9.88769e-02
# Iter 568, Loss_f: 9.88303e-02
# Iter 569, Loss_f: 9.87744e-02
# Iter 570, Loss_f: 9.87364e-02
# Iter 571, Loss_f: 9.86773e-02
# Iter 572, Loss_f: 9.86168e-02
# Iter 573, Loss_f: 9.85650e-02
# Iter 574, Loss_f: 9.85040e-02
# Iter 575, Loss_f: 9.84579e-02
# Iter 576, Loss_f: 9.84220e-02
# Iter 577, Loss_f: 9.83812e-02
# Iter 578, Loss_f: 9.83141e-02
# Iter 579, Loss_f: 9.81884e-02
# Iter 580, Loss_f: 9.80313e-02
# Iter 581, Loss_f: 9.87367e-02
# Iter 582, Loss_f: 9.79565e-02
# Iter 583, Loss_f: 9.78095e-02
# Iter 584, Loss_f: 9.78095e-02
# Iter 585, Loss_f: 9.76387e-02
# Iter 586, Loss_f: 9.75035e-02
# Iter 587, Loss_f: 9.74676e-02
# Iter 588, Loss_f: 9.70957e-02
# Iter 589, Loss_f: 9.74704e-02
# Iter 590, Loss_f: 9.69664e-02
# Iter 591, Loss_f: 9.67405e-02
# Iter 592, Loss_f: 9.64734e-02
# Iter 593, Loss_f: 9.63814e-02
# Iter 594, Loss_f: 9.62438e-02
# Iter 595, Loss_f: 9.61798e-02
# Iter 596, Loss_f: 9.61022e-02
# Iter 597, Loss_f: 9.60171e-02
# Iter 598, Loss_f: 9.59108e-02
# Iter 599, Loss_f: 9.60068e-02
# Iter 600, Loss_f: 9.58456e-02
# Iter 601, Loss_f: 9.57325e-02
# Iter 602, Loss_f: 9.56533e-02
# Iter 603, Loss_f: 9.54556e-02
# Iter 604, Loss_f: 9.54556e-02
# Iter 605, Loss_f: 9.53013e-02
# Iter 606, Loss_f: 9.51500e-02
# Iter 607, Loss_f: 9.91059e-02
# Iter 608, Loss_f: 9.49776e-02
# Iter 609, Loss_f: 9.45504e-02
# Iter 610, Loss_f: 9.47922e-02
# Iter 611, Loss_f: 9.44159e-02
# Iter 612, Loss_f: 9.41366e-02
# Iter 613, Loss_f: 9.41423e-02
# Iter 614, Loss_f: 9.40097e-02
# Iter 615, Loss_f: 9.38728e-02
# Iter 616, Loss_f: 9.37018e-02
# Iter 617, Loss_f: 9.41527e-02
# Iter 618, Loss_f: 9.35447e-02
# Iter 619, Loss_f: 9.33962e-02
# Iter 620, Loss_f: 9.33268e-02
# Iter 621, Loss_f: 9.31379e-02
# Iter 622, Loss_f: 9.31767e-02
# Iter 623, Loss_f: 9.30599e-02
# Iter 624, Loss_f: 9.30599e-02
# Iter 625, Loss_f: 9.29650e-02
# Iter 626, Loss_f: 9.28349e-02
# Iter 627, Loss_f: 9.27338e-02
# Iter 628, Loss_f: 9.26348e-02
# Iter 629, Loss_f: 9.25472e-02
# Iter 630, Loss_f: 9.24269e-02
# Iter 631, Loss_f: 9.22833e-02
# Iter 632, Loss_f: 9.21362e-02
# Iter 633, Loss_f: 9.20589e-02
# Iter 634, Loss_f: 9.20195e-02
# Iter 635, Loss_f: 9.19870e-02
# Iter 636, Loss_f: 9.19231e-02
# Iter 637, Loss_f: 9.18933e-02
# Iter 638, Loss_f: 9.18509e-02
# Iter 639, Loss_f: 9.37264e-02
# Iter 640, Loss_f: 9.18432e-02
# Iter 641, Loss_f: 9.17740e-02
# Iter 642, Loss_f: 9.17036e-02
# Iter 643, Loss_f: 9.16306e-02
# Iter 644, Loss_f: 9.16306e-02
# Iter 645, Loss_f: 9.14960e-02
# Iter 646, Loss_f: 9.13970e-02
# Iter 647, Loss_f: 9.13073e-02
# Iter 648, Loss_f: 9.12287e-02
# Iter 649, Loss_f: 9.11732e-02
# Iter 650, Loss_f: 9.11350e-02
# Iter 651, Loss_f: 9.11110e-02
# Iter 652, Loss_f: 9.11755e-02
# Iter 653, Loss_f: 9.10940e-02
# Iter 654, Loss_f: 9.10927e-02
# Iter 655, Loss_f: 9.10605e-02
# Iter 656, Loss_f: 9.10096e-02
# Iter 657, Loss_f: 9.09093e-02
# Iter 658, Loss_f: 9.06905e-02
# Iter 659, Loss_f: 9.22869e-02
# Iter 660, Loss_f: 9.05687e-02
# Iter 661, Loss_f: 9.02801e-02
# Iter 662, Loss_f: 9.14732e-02
# Iter 663, Loss_f: 9.00578e-02
# Iter 664, Loss_f: 9.00578e-02
# Iter 665, Loss_f: 8.98078e-02
# Iter 666, Loss_f: 8.93564e-02
# Iter 667, Loss_f: 8.91967e-02
# Iter 668, Loss_f: 8.90215e-02
# Iter 669, Loss_f: 8.88805e-02
# Iter 670, Loss_f: 8.88626e-02
# Iter 671, Loss_f: 8.87140e-02
# Iter 672, Loss_f: 8.85270e-02
# Iter 673, Loss_f: 8.84221e-02
# Iter 674, Loss_f: 8.83515e-02
# Iter 675, Loss_f: 8.83347e-02
# Iter 676, Loss_f: 8.82763e-02
# Iter 677, Loss_f: 8.82465e-02
# Iter 678, Loss_f: 8.82131e-02
# Iter 679, Loss_f: 8.81904e-02
# Iter 680, Loss_f: 8.81748e-02
# Iter 681, Loss_f: 8.81643e-02
# Iter 682, Loss_f: 8.81614e-02
# Iter 683, Loss_f: 8.81524e-02
# Iter 684, Loss_f: 8.81524e-02
# Iter 685, Loss_f: 8.81471e-02
# Iter 686, Loss_f: 8.81436e-02
# Iter 687, Loss_f: 8.81370e-02
# Iter 688, Loss_f: 8.81298e-02
# Iter 689, Loss_f: 8.81075e-02
# Iter 690, Loss_f: 8.80748e-02
# Iter 691, Loss_f: 8.80150e-02
# Iter 692, Loss_f: 1.03893e-01
# Iter 693, Loss_f: 8.80334e-02
# Iter 694, Loss_f: 8.80070e-02
# Iter 695, Loss_f: 8.79156e-02
# Iter 696, Loss_f: 8.78230e-02
# Iter 697, Loss_f: 8.81094e-02
# Iter 698, Loss_f: 8.77816e-02
# Iter 699, Loss_f: 8.77374e-02
# Iter 700, Loss_f: 8.77228e-02
# Iter 701, Loss_f: 8.76916e-02
# Iter 702, Loss_f: 8.76695e-02
# Iter 703, Loss_f: 8.76388e-02
# Iter 704, Loss_f: 8.76388e-02
# Iter 705, Loss_f: 8.79886e-02
# Iter 706, Loss_f: 8.76269e-02
# Iter 707, Loss_f: 8.75906e-02
# Iter 708, Loss_f: 8.75680e-02
# Iter 709, Loss_f: 8.75312e-02
# Iter 710, Loss_f: 8.75082e-02
# Iter 711, Loss_f: 8.74702e-02
# Iter 712, Loss_f: 8.74319e-02
# Iter 713, Loss_f: 8.73881e-02
# Iter 714, Loss_f: 8.73407e-02
# Iter 715, Loss_f: 8.73065e-02
# Iter 716, Loss_f: 8.72604e-02
# Iter 717, Loss_f: 8.71913e-02
# Iter 718, Loss_f: 8.71493e-02
# Iter 719, Loss_f: 8.70679e-02
# Iter 720, Loss_f: 8.70089e-02
# Iter 721, Loss_f: 8.68937e-02
# Iter 722, Loss_f: 8.69615e-02
# Iter 723, Loss_f: 8.68235e-02
# Iter 724, Loss_f: 8.68235e-02
# Iter 725, Loss_f: 8.67378e-02
# Iter 726, Loss_f: 8.66116e-02
# Iter 727, Loss_f: 8.65498e-02
# Iter 728, Loss_f: 8.65073e-02
# Iter 729, Loss_f: 8.64684e-02
# Iter 730, Loss_f: 8.64323e-02
# Iter 731, Loss_f: 8.64586e-02
# Iter 732, Loss_f: 8.64013e-02
# Iter 733, Loss_f: 1.08426e-01
# Iter 734, Loss_f: 8.64241e-02
# Iter 735, Loss_f: 8.63958e-02
# Iter 736, Loss_f: 8.63553e-02
# Iter 737, Loss_f: 8.63096e-02
# Iter 738, Loss_f: 8.62522e-02
# Iter 739, Loss_f: 8.61556e-02
# Iter 740, Loss_f: 8.60614e-02
# Iter 741, Loss_f: 8.59037e-02
# Iter 742, Loss_f: 8.57327e-02
# Iter 743, Loss_f: 8.55808e-02
# Iter 744, Loss_f: 8.55808e-02
# Iter 745, Loss_f: 9.99125e-02
# Iter 746, Loss_f: 8.55293e-02
# Iter 747, Loss_f: 8.53127e-02
# Iter 748, Loss_f: 8.51415e-02
# Iter 749, Loss_f: 8.81178e-02
# Iter 750, Loss_f: 8.50336e-02
# Iter 751, Loss_f: 8.48190e-02
# Iter 752, Loss_f: 8.48224e-02
# Iter 753, Loss_f: 8.46984e-02
# Iter 754, Loss_f: 8.45770e-02
# Iter 755, Loss_f: 8.43403e-02
# Iter 756, Loss_f: 8.40986e-02
# Iter 757, Loss_f: 8.41212e-02
# Iter 758, Loss_f: 8.39664e-02
# Iter 759, Loss_f: 8.43484e-02
# Iter 760, Loss_f: 8.38332e-02
# Iter 761, Loss_f: 8.38100e-02
# Iter 762, Loss_f: 8.36079e-02
# Iter 763, Loss_f: 8.39782e-02
# Iter 764, Loss_f: 8.33919e-02
# Iter 765, Loss_f: 8.33919e-02
# Iter 766, Loss_f: 8.31175e-02
# Iter 767, Loss_f: 8.33864e-02
# Iter 768, Loss_f: 8.30183e-02
# Iter 769, Loss_f: 8.33780e-02
# Iter 770, Loss_f: 8.28844e-02
# Iter 771, Loss_f: 8.25513e-02
# Iter 772, Loss_f: 8.23988e-02
# Iter 773, Loss_f: 8.37722e-02
# Iter 774, Loss_f: 8.21302e-02
# Iter 775, Loss_f: 8.20322e-02
# Iter 776, Loss_f: 8.15065e-02
# Iter 777, Loss_f: 8.15596e-02
# Iter 778, Loss_f: 8.12197e-02
# Iter 779, Loss_f: 8.09435e-02
# Iter 780, Loss_f: 8.07807e-02
# Iter 781, Loss_f: 8.04474e-02
# Iter 782, Loss_f: 8.04264e-02
# Iter 783, Loss_f: 8.01656e-02
# Iter 784, Loss_f: 9.10196e-02
# Iter 785, Loss_f: 8.03808e-02
# Iter 786, Loss_f: 8.01002e-02
# Iter 787, Loss_f: 8.01002e-02
# Iter 788, Loss_f: 8.00256e-02
# Iter 789, Loss_f: 7.99473e-02
# Iter 790, Loss_f: 7.98276e-02
# Iter 791, Loss_f: 7.97535e-02
# Iter 792, Loss_f: 7.96892e-02
# Iter 793, Loss_f: 7.96132e-02
# Iter 794, Loss_f: 7.95368e-02
# Iter 795, Loss_f: 7.94465e-02
# Iter 796, Loss_f: 7.92888e-02
# Iter 797, Loss_f: 7.91081e-02
# Iter 798, Loss_f: 7.89371e-02
# Iter 799, Loss_f: 7.87873e-02
# Iter 800, Loss_f: 7.87322e-02
# Iter 801, Loss_f: 7.86171e-02
# Iter 802, Loss_f: 7.85123e-02
# Iter 803, Loss_f: 7.84656e-02
# Iter 804, Loss_f: 7.83630e-02
# Iter 805, Loss_f: 7.81838e-02
# Iter 806, Loss_f: 7.78609e-02
# Iter 807, Loss_f: 7.78609e-02
# Iter 808, Loss_f: 7.75145e-02
# Iter 809, Loss_f: 7.74151e-02
# Iter 810, Loss_f: 7.71822e-02
# Iter 811, Loss_f: 7.70608e-02
# Iter 812, Loss_f: 7.69674e-02
# Iter 813, Loss_f: 7.68315e-02
# Iter 814, Loss_f: 7.68879e-02
# Iter 815, Loss_f: 7.67601e-02
# Iter 816, Loss_f: 7.66570e-02
# Iter 817, Loss_f: 7.65910e-02
# Iter 818, Loss_f: 7.64572e-02
# Iter 819, Loss_f: 7.63448e-02
# Iter 820, Loss_f: 7.65303e-02
# Iter 821, Loss_f: 7.63054e-02
# Iter 822, Loss_f: 7.62284e-02
# Iter 823, Loss_f: 7.61764e-02
# Iter 824, Loss_f: 7.60977e-02
# Iter 825, Loss_f: 7.60302e-02
# Iter 826, Loss_f: 7.59475e-02
# Iter 827, Loss_f: 7.59475e-02
# Iter 828, Loss_f: 7.58375e-02
# Iter 829, Loss_f: 7.56373e-02
# Iter 830, Loss_f: 7.56422e-02
# Iter 831, Loss_f: 7.55146e-02
# Iter 832, Loss_f: 7.53996e-02
# Iter 833, Loss_f: 7.51646e-02
# Iter 834, Loss_f: 7.50755e-02
# Iter 835, Loss_f: 7.50152e-02
# Iter 836, Loss_f: 7.49605e-02
# Iter 837, Loss_f: 7.49068e-02
# Iter 838, Loss_f: 7.48414e-02
# Iter 839, Loss_f: 7.47352e-02
# Iter 840, Loss_f: 7.46013e-02
# Iter 841, Loss_f: 7.45190e-02
# Iter 842, Loss_f: 7.44840e-02
# Iter 843, Loss_f: 7.44920e-02
# Iter 844, Loss_f: 7.44583e-02
# Iter 845, Loss_f: 7.44376e-02
# Iter 846, Loss_f: 7.44057e-02
# Iter 847, Loss_f: 7.44057e-02
# Iter 848, Loss_f: 7.61170e-02
# Iter 849, Loss_f: 7.43946e-02
# Iter 850, Loss_f: 7.43601e-02
# Iter 851, Loss_f: 7.42128e-02
# Iter 852, Loss_f: 7.49387e-02
# Iter 853, Loss_f: 7.41425e-02
# Iter 854, Loss_f: 7.40009e-02
# Iter 855, Loss_f: 7.38877e-02
# Iter 856, Loss_f: 7.39347e-02
# Iter 857, Loss_f: 7.38427e-02
# Iter 858, Loss_f: 7.37568e-02
# Iter 859, Loss_f: 7.36250e-02
# Iter 860, Loss_f: 7.34749e-02
# Iter 861, Loss_f: 7.35547e-02
# Iter 862, Loss_f: 7.33943e-02
# Iter 863, Loss_f: 7.33211e-02
# Iter 864, Loss_f: 7.38134e-02
# Iter 865, Loss_f: 7.32546e-02
# Iter 866, Loss_f: 7.31141e-02
# Iter 867, Loss_f: 7.31141e-02
# Iter 868, Loss_f: 7.27996e-02
# Iter 869, Loss_f: 7.35250e-02
# Iter 870, Loss_f: 7.27396e-02
# Iter 871, Loss_f: 7.25102e-02
# Iter 872, Loss_f: 7.24093e-02
# Iter 873, Loss_f: 7.25117e-02
# Iter 874, Loss_f: 7.22603e-02
# Iter 875, Loss_f: 7.21410e-02
# Iter 876, Loss_f: 7.20204e-02
# Iter 877, Loss_f: 7.19218e-02
# Iter 878, Loss_f: 7.19256e-02
# Iter 879, Loss_f: 7.18871e-02
# Iter 880, Loss_f: 7.18415e-02
# Iter 881, Loss_f: 7.17988e-02
# Iter 882, Loss_f: 7.21420e-02
# Iter 883, Loss_f: 7.17683e-02
# Iter 884, Loss_f: 7.16706e-02
# Iter 885, Loss_f: 7.16014e-02
# Iter 886, Loss_f: 7.15050e-02
# Iter 887, Loss_f: 7.15050e-02
# Iter 888, Loss_f: 7.18065e-02
# Iter 889, Loss_f: 7.14560e-02
# Iter 890, Loss_f: 7.14067e-02
# Iter 891, Loss_f: 7.13628e-02
# Iter 892, Loss_f: 7.13356e-02
# Iter 893, Loss_f: 7.12999e-02
# Iter 894, Loss_f: 7.12696e-02
# Iter 895, Loss_f: 7.12221e-02
# Iter 896, Loss_f: 7.17005e-02
# Iter 897, Loss_f: 7.12080e-02
# Iter 898, Loss_f: 7.12738e-02
# Iter 899, Loss_f: 7.11764e-02
# Iter 900, Loss_f: 7.11111e-02
# Iter 901, Loss_f: 7.11508e-02
# Iter 902, Loss_f: 7.10816e-02
# Iter 903, Loss_f: 7.10323e-02
# Iter 904, Loss_f: 7.09891e-02
# Iter 905, Loss_f: 7.09219e-02
# Iter 906, Loss_f: 7.08799e-02
# Iter 907, Loss_f: 7.08799e-02
# Iter 908, Loss_f: 7.08341e-02
# Iter 909, Loss_f: 7.07770e-02
# Iter 910, Loss_f: 7.07231e-02
# Iter 911, Loss_f: 7.06763e-02
# Iter 912, Loss_f: 7.08016e-02
# Iter 913, Loss_f: 7.06375e-02
# Iter 914, Loss_f: 7.05874e-02
# Iter 915, Loss_f: 7.05364e-02
# Iter 916, Loss_f: 7.04748e-02
# Iter 917, Loss_f: 7.04158e-02
# Iter 918, Loss_f: 7.03713e-02
# Iter 919, Loss_f: 7.03325e-02
# Iter 920, Loss_f: 7.02696e-02
# Iter 921, Loss_f: 7.02205e-02
# Iter 922, Loss_f: 7.01810e-02
# Iter 923, Loss_f: 7.01535e-02
# Iter 924, Loss_f: 7.00978e-02
# Iter 925, Loss_f: 7.00166e-02
# Iter 926, Loss_f: 6.99602e-02
# Iter 927, Loss_f: 6.99602e-02
# Iter 928, Loss_f: 6.99105e-02
# Iter 929, Loss_f: 6.98884e-02
# Iter 930, Loss_f: 6.98496e-02
# Iter 931, Loss_f: 6.98013e-02
# Iter 932, Loss_f: 6.97365e-02
# Iter 933, Loss_f: 6.96504e-02
# Iter 934, Loss_f: 6.95757e-02
# Iter 935, Loss_f: 6.95905e-02
# Iter 936, Loss_f: 6.95184e-02
# Iter 937, Loss_f: 6.94416e-02
# Iter 938, Loss_f: 6.93610e-02
# Iter 939, Loss_f: 6.96828e-02
# Iter 940, Loss_f: 6.93128e-02
# Iter 941, Loss_f: 6.91970e-02
# Iter 942, Loss_f: 6.90418e-02
# Iter 943, Loss_f: 6.88192e-02
# Iter 944, Loss_f: 6.92313e-02
# Iter 945, Loss_f: 6.86418e-02
# Iter 946, Loss_f: 6.88135e-02
# Iter 947, Loss_f: 6.85482e-02
# Iter 948, Loss_f: 6.85482e-02
# Iter 949, Loss_f: 6.84281e-02
# Iter 950, Loss_f: 6.85011e-02
# Iter 951, Loss_f: 6.82786e-02
# Iter 952, Loss_f: 6.88051e-02
# Iter 953, Loss_f: 6.81884e-02
# Iter 954, Loss_f: 6.81571e-02
# Iter 955, Loss_f: 6.80646e-02
# Iter 956, Loss_f: 6.80225e-02
# Iter 957, Loss_f: 6.79756e-02
# Iter 958, Loss_f: 6.79095e-02
# Iter 959, Loss_f: 6.78397e-02
# Iter 960, Loss_f: 6.77878e-02
# Iter 961, Loss_f: 6.77122e-02
# Iter 962, Loss_f: 6.76366e-02
# Iter 963, Loss_f: 6.75689e-02
# Iter 964, Loss_f: 6.74899e-02
# Iter 965, Loss_f: 6.74335e-02
# Iter 966, Loss_f: 6.73940e-02
# Iter 967, Loss_f: 6.73351e-02
# Iter 968, Loss_f: 6.73351e-02
# Iter 969, Loss_f: 6.72859e-02
# Iter 970, Loss_f: 6.72250e-02
# Iter 971, Loss_f: 6.71729e-02
# Iter 972, Loss_f: 6.71090e-02
# Iter 973, Loss_f: 6.70509e-02
# Iter 974, Loss_f: 6.69754e-02
# Iter 975, Loss_f: 6.69303e-02
# Iter 976, Loss_f: 6.68980e-02
# Iter 977, Loss_f: 6.68402e-02
# Iter 978, Loss_f: 6.67464e-02
# Iter 979, Loss_f: 6.66626e-02
# Iter 980, Loss_f: 6.65622e-02
# Iter 981, Loss_f: 6.67345e-02
# Iter 982, Loss_f: 6.64853e-02
# Iter 983, Loss_f: 6.66954e-02
# Iter 984, Loss_f: 6.63665e-02
# Iter 985, Loss_f: 6.62323e-02
# Iter 986, Loss_f: 6.61812e-02
# Iter 987, Loss_f: 6.61012e-02
# Iter 988, Loss_f: 6.61012e-02
# Iter 989, Loss_f: 6.59922e-02
# Iter 990, Loss_f: 6.59290e-02
# Iter 991, Loss_f: 6.58447e-02
# Iter 992, Loss_f: 6.61608e-02
# Iter 993, Loss_f: 6.58016e-02
# Iter 994, Loss_f: 6.56223e-02
# Iter 995, Loss_f: 6.54134e-02
# Iter 996, Loss_f: 6.50849e-02
# Iter 997, Loss_f: 6.65929e-02
# Iter 998, Loss_f: 6.49470e-02
# Iter 999, Loss_f: 6.93960e-02
# Iter 1000, Loss_f: 6.48157e-02
# Iter 1001, Loss_f: 6.60083e-02
# Iter 1002, Loss_f: 6.45960e-02
# Iter 1003, Loss_f: 6.46368e-02
# Iter 1004, Loss_f: 6.43968e-02
# Iter 1005, Loss_f: 6.41570e-02
# Iter 1006, Loss_f: 6.42368e-02
# Iter 1007, Loss_f: 6.39356e-02
# Iter 1008, Loss_f: 6.39356e-02
# Iter 1009, Loss_f: 6.49609e-02
# Iter 1010, Loss_f: 6.36944e-02
# Iter 1011, Loss_f: 6.33971e-02
# Iter 1012, Loss_f: 6.30814e-02
# Iter 1013, Loss_f: 6.29055e-02
# Iter 1014, Loss_f: 6.27281e-02
# Iter 1015, Loss_f: 6.25160e-02
# Iter 1016, Loss_f: 6.24325e-02
# Iter 1017, Loss_f: 6.24041e-02
# Iter 1018, Loss_f: 6.23281e-02
# Iter 1019, Loss_f: 6.24418e-02
# Iter 1020, Loss_f: 6.22348e-02
# Iter 1021, Loss_f: 6.21955e-02
# Iter 1022, Loss_f: 6.21428e-02
# Iter 1023, Loss_f: 6.20925e-02
# Iter 1024, Loss_f: 6.20390e-02
# Iter 1025, Loss_f: 6.19833e-02
# Iter 1026, Loss_f: 6.18946e-02
# Iter 1027, Loss_f: 6.18733e-02
# Iter 1028, Loss_f: 6.18733e-02
# Iter 1029, Loss_f: 6.17678e-02
# Iter 1030, Loss_f: 6.17323e-02
# Iter 1031, Loss_f: 6.16990e-02
# Iter 1032, Loss_f: 6.16451e-02
# Iter 1033, Loss_f: 6.16187e-02
# Iter 1034, Loss_f: 6.15886e-02
# Iter 1035, Loss_f: 6.15611e-02
# Iter 1036, Loss_f: 6.15253e-02
# Iter 1037, Loss_f: 6.14927e-02
# Iter 1038, Loss_f: 6.14722e-02
# Iter 1039, Loss_f: 6.14358e-02
# Iter 1040, Loss_f: 6.13778e-02
# Iter 1041, Loss_f: 6.12940e-02
# Iter 1042, Loss_f: 6.12267e-02
# Iter 1043, Loss_f: 7.39572e-02
# Iter 1044, Loss_f: 6.12421e-02
# Iter 1045, Loss_f: 6.11679e-02
# Iter 1046, Loss_f: 6.10165e-02
# Iter 1047, Loss_f: 6.13036e-02
# Iter 1048, Loss_f: 6.08381e-02
# Iter 1049, Loss_f: 6.08381e-02
# Iter 1050, Loss_f: 6.05596e-02
# Iter 1051, Loss_f: 6.10055e-02
# Iter 1052, Loss_f: 6.03951e-02
# Iter 1053, Loss_f: 6.04379e-02
# Iter 1054, Loss_f: 6.02346e-02
# Iter 1055, Loss_f: 6.01703e-02
# Iter 1056, Loss_f: 6.00478e-02
# Iter 1057, Loss_f: 6.00775e-02
# Iter 1058, Loss_f: 6.00149e-02
# Iter 1059, Loss_f: 5.99837e-02
# Iter 1060, Loss_f: 5.99538e-02
# Iter 1061, Loss_f: 5.99307e-02
# Iter 1062, Loss_f: 5.98957e-02
# Iter 1063, Loss_f: 5.98665e-02
# Iter 1064, Loss_f: 5.98363e-02
# Iter 1065, Loss_f: 5.98364e-02
# Iter 1066, Loss_f: 5.97998e-02
# Iter 1067, Loss_f: 5.97433e-02
# Iter 1068, Loss_f: 5.96289e-02
# Iter 1069, Loss_f: 5.96289e-02
# Iter 1070, Loss_f: 5.94782e-02
# Iter 1071, Loss_f: 6.25902e-02
# Iter 1072, Loss_f: 5.94304e-02
# Iter 1073, Loss_f: 5.91996e-02
# Iter 1074, Loss_f: 5.89197e-02
# Iter 1075, Loss_f: 5.88723e-02
# Iter 1076, Loss_f: 5.85328e-02
# Iter 1077, Loss_f: 2.17640e-01
# Iter 1078, Loss_f: 5.83857e-02
# Iter 1079, Loss_f: 5.82621e-02
# Iter 1080, Loss_f: 5.79067e-02
# Iter 1081, Loss_f: 6.67238e-02
# Iter 1082, Loss_f: 5.77257e-02
# Iter 1083, Loss_f: 5.76586e-02
# Iter 1084, Loss_f: 5.74160e-02
# Iter 1085, Loss_f: 5.79843e-02
# Iter 1086, Loss_f: 5.69480e-02
# Iter 1087, Loss_f: 5.69821e-02
# Iter 1088, Loss_f: 5.65575e-02
# Iter 1089, Loss_f: 5.65575e-02
# Iter 1090, Loss_f: 5.62775e-02
# Iter 1091, Loss_f: 5.61504e-02
# Iter 1092, Loss_f: 5.59784e-02
# Iter 1093, Loss_f: 5.58520e-02
# Iter 1094, Loss_f: 5.57217e-02
# Iter 1095, Loss_f: 5.55727e-02
# Iter 1096, Loss_f: 5.58427e-02
# Iter 1097, Loss_f: 5.54436e-02
# Iter 1098, Loss_f: 5.53335e-02
# Iter 1099, Loss_f: 5.53267e-02
# Iter 1100, Loss_f: 5.52923e-02
# Iter 1101, Loss_f: 5.52664e-02
# Iter 1102, Loss_f: 5.52354e-02
# Iter 1103, Loss_f: 5.52133e-02
# Iter 1104, Loss_f: 5.51894e-02
# Iter 1105, Loss_f: 5.51719e-02
# Iter 1106, Loss_f: 5.52008e-02
# Iter 1107, Loss_f: 5.51440e-02
# Iter 1108, Loss_f: 5.51143e-02
# Iter 1109, Loss_f: 5.51143e-02
# Iter 1110, Loss_f: 5.50754e-02
# Iter 1111, Loss_f: 5.50525e-02
# Iter 1112, Loss_f: 5.50218e-02
# Iter 1113, Loss_f: 5.49893e-02
# Iter 1114, Loss_f: 5.49639e-02
# Iter 1115, Loss_f: 5.49302e-02
# Iter 1116, Loss_f: 5.48809e-02
# Iter 1117, Loss_f: 5.47887e-02
# Iter 1118, Loss_f: 5.46639e-02
# Iter 1119, Loss_f: 5.45448e-02
# Iter 1120, Loss_f: 5.46351e-02
# Iter 1121, Loss_f: 5.44946e-02
# Iter 1122, Loss_f: 5.42937e-02
# Iter 1123, Loss_f: 5.40594e-02
# Iter 1124, Loss_f: 5.38818e-02
# Iter 1125, Loss_f: 5.35884e-02
# Iter 1126, Loss_f: 5.33881e-02
# Iter 1127, Loss_f: 5.37604e-02
# Iter 1128, Loss_f: 5.31798e-02
# Iter 1129, Loss_f: 5.31798e-02
# Iter 1130, Loss_f: 5.29339e-02
# Iter 1131, Loss_f: 5.29680e-02
# Iter 1132, Loss_f: 5.28327e-02
# Iter 1133, Loss_f: 5.26677e-02
# Iter 1134, Loss_f: 5.25570e-02
# Iter 1135, Loss_f: 5.24460e-02
# Iter 1136, Loss_f: 5.42689e-02
# Iter 1137, Loss_f: 5.23374e-02
# Iter 1138, Loss_f: 5.21003e-02
# Iter 1139, Loss_f: 5.18499e-02
# Iter 1140, Loss_f: 5.28278e-02
# Iter 1141, Loss_f: 5.16261e-02
# Iter 1142, Loss_f: 5.15301e-02
# Iter 1143, Loss_f: 5.15031e-02
# Iter 1144, Loss_f: 5.14215e-02
# Iter 1145, Loss_f: 5.67402e-02
# Iter 1146, Loss_f: 5.13605e-02
# Iter 1147, Loss_f: 5.11775e-02
# Iter 1148, Loss_f: 5.12275e-02
# Iter 1149, Loss_f: 5.10523e-02
# Iter 1150, Loss_f: 5.10523e-02
# Iter 1151, Loss_f: 5.14719e-02
# Iter 1152, Loss_f: 5.09920e-02
# Iter 1153, Loss_f: 5.09557e-02
# Iter 1154, Loss_f: 5.08883e-02
# Iter 1155, Loss_f: 5.08461e-02
# Iter 1156, Loss_f: 5.07735e-02
# Iter 1157, Loss_f: 5.07359e-02
# Iter 1158, Loss_f: 5.07172e-02
# Iter 1159, Loss_f: 5.06913e-02
# Iter 1160, Loss_f: 5.06661e-02
# Iter 1161, Loss_f: 5.06074e-02
# Iter 1162, Loss_f: 5.04636e-02
# Iter 1163, Loss_f: 5.03099e-02
# Iter 1164, Loss_f: 5.02169e-02
# Iter 1165, Loss_f: 5.02641e-02
# Iter 1166, Loss_f: 5.01961e-02
# Iter 1167, Loss_f: 5.01557e-02
# Iter 1168, Loss_f: 5.01343e-02
# Iter 1169, Loss_f: 5.01253e-02
# Iter 1170, Loss_f: 5.01253e-02
# Iter 1171, Loss_f: 5.01152e-02
# Iter 1172, Loss_f: 5.01062e-02
# Iter 1173, Loss_f: 5.00961e-02
# Iter 1174, Loss_f: 5.00851e-02
# Iter 1175, Loss_f: 5.00561e-02
# Iter 1176, Loss_f: 5.00255e-02
# Iter 1177, Loss_f: 4.99997e-02
# Iter 1178, Loss_f: 4.99705e-02
# Iter 1179, Loss_f: 5.04860e-02
# Iter 1180, Loss_f: 4.99595e-02
# Iter 1181, Loss_f: 5.92541e-02
# Iter 1182, Loss_f: 4.99420e-02
# Iter 1183, Loss_f: 4.98947e-02
# Iter 1184, Loss_f: 4.97760e-02
# Iter 1185, Loss_f: 4.96701e-02
# Iter 1186, Loss_f: 4.95819e-02
# Iter 1187, Loss_f: 5.10402e-02
# Iter 1188, Loss_f: 4.95227e-02
# Iter 1189, Loss_f: 4.95420e-02
# Iter 1190, Loss_f: 4.94711e-02
# Iter 1191, Loss_f: 4.94711e-02
# Iter 1192, Loss_f: 4.92142e-02
# Iter 1193, Loss_f: 4.90757e-02
# Iter 1194, Loss_f: 4.90114e-02
# Iter 1195, Loss_f: 4.89859e-02
# Iter 1196, Loss_f: 4.88966e-02
# Iter 1197, Loss_f: 4.88076e-02
# Iter 1198, Loss_f: 4.86774e-02
# Iter 1199, Loss_f: 4.85149e-02
# Iter 1200, Loss_f: 4.85226e-02
# Iter 1201, Loss_f: 4.84029e-02
# Iter 1202, Loss_f: 4.83394e-02
# Iter 1203, Loss_f: 4.82318e-02
# Iter 1204, Loss_f: 4.82030e-02
# Iter 1205, Loss_f: 5.83782e-02
# Iter 1206, Loss_f: 4.81873e-02
# Iter 1207, Loss_f: 4.81807e-02
# Iter 1208, Loss_f: 4.94993e-02
# Iter 1209, Loss_f: 4.81279e-02
# Iter 1210, Loss_f: 4.80614e-02
# Iter 1211, Loss_f: 4.80614e-02
# Iter 1212, Loss_f: 4.82844e-02
# Iter 1213, Loss_f: 4.80517e-02
# Iter 1214, Loss_f: 4.80231e-02
# Iter 1215, Loss_f: 4.80021e-02
# Iter 1216, Loss_f: 4.79867e-02
# Iter 1217, Loss_f: 4.79747e-02
# Iter 1218, Loss_f: 4.79610e-02
# Iter 1219, Loss_f: 4.79489e-02
# Iter 1220, Loss_f: 4.79376e-02
# Iter 1221, Loss_f: 4.79169e-02
# Iter 1222, Loss_f: 4.78355e-02
# Iter 1223, Loss_f: 4.77216e-02
# Iter 1224, Loss_f: 4.82922e-02
# Iter 1225, Loss_f: 4.76754e-02
# Iter 1226, Loss_f: 5.07953e-02
# Iter 1227, Loss_f: 4.74754e-02
# Iter 1228, Loss_f: 4.74621e-02
# Iter 1229, Loss_f: 4.73420e-02
# Iter 1230, Loss_f: 4.69446e-02
# Iter 1231, Loss_f: 4.69446e-02
# Iter 1232, Loss_f: 4.66401e-02
# Iter 1233, Loss_f: 3.81557e+02
# Iter 1234, Loss_f: 4.66399e-02
# Iter 1235, Loss_f: 2.58585e-01
# Iter 1236, Loss_f: 5.05441e-02
# Iter 1237, Loss_f: 4.65911e-02
# Iter 1238, Loss_f: 4.65070e-02
# Iter 1239, Loss_f: 4.78980e-02
# Iter 1240, Loss_f: 4.62961e-02
# Iter 1241, Loss_f: 4.61381e-02
# Iter 1242, Loss_f: 4.58075e-02
# Iter 1243, Loss_f: 2.94127e-01
# Iter 1244, Loss_f: 4.59523e-02
# Iter 1245, Loss_f: 4.57641e-02
# Iter 1246, Loss_f: 4.54931e-02
# Iter 1247, Loss_f: 4.54519e-02
# Iter 1248, Loss_f: 4.52942e-02
# Iter 1249, Loss_f: 4.49999e-02
# Iter 1250, Loss_f: 4.48112e-02
# Iter 1251, Loss_f: 4.48112e-02
# Iter 1252, Loss_f: 4.46872e-02
# Iter 1253, Loss_f: 4.45512e-02
# Iter 1254, Loss_f: 4.44408e-02
# Iter 1255, Loss_f: 4.43274e-02
# Iter 1256, Loss_f: 4.42680e-02
# Iter 1257, Loss_f: 4.40837e-02
# Iter 1258, Loss_f: 4.40215e-02
# Iter 1259, Loss_f: 4.40567e-02
# Iter 1260, Loss_f: 4.39823e-02
# Iter 1261, Loss_f: 4.39438e-02
# Iter 1262, Loss_f: 4.39178e-02
# Iter 1263, Loss_f: 4.39000e-02
# Iter 1264, Loss_f: 4.38889e-02
# Iter 1265, Loss_f: 4.38802e-02
# Iter 1266, Loss_f: 4.38715e-02
# Iter 1267, Loss_f: 4.38613e-02
# Iter 1268, Loss_f: 4.38909e-02
# Iter 1269, Loss_f: 4.38492e-02
# Iter 1270, Loss_f: 4.38368e-02
# Iter 1271, Loss_f: 4.38368e-02
# Iter 1272, Loss_f: 4.38126e-02
# Iter 1273, Loss_f: 4.38065e-02
# Iter 1274, Loss_f: 4.37998e-02
# Iter 1275, Loss_f: 4.37946e-02
# Iter 1276, Loss_f: 4.93957e-02
# Iter 1277, Loss_f: 4.37923e-02
# Iter 1278, Loss_f: 4.37842e-02
# Iter 1279, Loss_f: 4.37731e-02
# Iter 1280, Loss_f: 4.37669e-02
# Iter 1281, Loss_f: 4.37551e-02
# Iter 1282, Loss_f: 4.37453e-02
# Iter 1283, Loss_f: 4.37319e-02
# Iter 1284, Loss_f: 4.37113e-02
# Iter 1285, Loss_f: 4.37044e-02
# Iter 1286, Loss_f: 4.36780e-02
# Iter 1287, Loss_f: 4.36462e-02
# Iter 1288, Loss_f: 4.35838e-02
# Iter 1289, Loss_f: 4.35524e-02
# Iter 1290, Loss_f: 4.35375e-02
# Iter 1291, Loss_f: 4.35375e-02
# Iter 1292, Loss_f: 4.35192e-02
# Iter 1293, Loss_f: 4.35018e-02
# Iter 1294, Loss_f: 4.34918e-02
# Iter 1295, Loss_f: 4.34670e-02
# Iter 1296, Loss_f: 4.35364e-02
# Iter 1297, Loss_f: 4.34481e-02
# Iter 1298, Loss_f: 4.34130e-02
# Iter 1299, Loss_f: 4.33656e-02
# Iter 1300, Loss_f: 4.35024e-02
# Iter 1301, Loss_f: 4.33458e-02
# Iter 1302, Loss_f: 4.34979e-02
# Iter 1303, Loss_f: 4.33340e-02
# Iter 1304, Loss_f: 4.32770e-02
# Iter 1305, Loss_f: 4.32237e-02
# Iter 1306, Loss_f: 4.31681e-02
# Iter 1307, Loss_f: 4.30849e-02
# Iter 1308, Loss_f: 4.30522e-02
# Iter 1309, Loss_f: 4.29668e-02
# Iter 1310, Loss_f: 4.28535e-02
# Iter 1311, Loss_f: 4.28535e-02
# Iter 1312, Loss_f: 4.29377e-02
# Iter 1313, Loss_f: 4.27436e-02
# Iter 1314, Loss_f: 4.26066e-02
# Iter 1315, Loss_f: 4.24756e-02
# Iter 1316, Loss_f: 4.29668e-02
# Iter 1317, Loss_f: 4.24222e-02
# Iter 1318, Loss_f: 4.23592e-02
# Iter 1319, Loss_f: 4.23278e-02
# Iter 1320, Loss_f: 4.22928e-02
# Iter 1321, Loss_f: 4.22758e-02
# Iter 1322, Loss_f: 4.22555e-02
# Iter 1323, Loss_f: 4.22426e-02
# Iter 1324, Loss_f: 4.22205e-02
# Iter 1325, Loss_f: 4.22817e-02
# Iter 1326, Loss_f: 4.22012e-02
# Iter 1327, Loss_f: 4.21634e-02
# Iter 1328, Loss_f: 4.22770e-02
# Iter 1329, Loss_f: 4.21051e-02
# Iter 1330, Loss_f: 4.20227e-02
# Iter 1331, Loss_f: 4.20227e-02
# Iter 1332, Loss_f: 4.19449e-02
# Iter 1333, Loss_f: 4.30496e-02
# Iter 1334, Loss_f: 4.19127e-02
# Iter 1335, Loss_f: 4.18492e-02
# Iter 1336, Loss_f: 4.18276e-02
# Iter 1337, Loss_f: 4.18039e-02
# Iter 1338, Loss_f: 4.18150e-02
# Iter 1339, Loss_f: 4.17959e-02
# Iter 1340, Loss_f: 4.18199e-02
# Iter 1341, Loss_f: 4.17576e-02
# Iter 1342, Loss_f: 4.19426e-02
# Iter 1343, Loss_f: 4.17462e-02
# Iter 1344, Loss_f: 4.17124e-02
# Iter 1345, Loss_f: 4.16684e-02
# Iter 1346, Loss_f: 4.16424e-02
# Iter 1347, Loss_f: 4.16224e-02
# Iter 1348, Loss_f: 4.15954e-02
# Iter 1349, Loss_f: 4.15837e-02
# Iter 1350, Loss_f: 4.15530e-02
# Iter 1351, Loss_f: 4.15530e-02
# Iter 1352, Loss_f: 4.15312e-02
# Iter 1353, Loss_f: 4.15452e-02
# Iter 1354, Loss_f: 4.15201e-02
# Iter 1355, Loss_f: 4.14983e-02
# Iter 1356, Loss_f: 4.14845e-02
# Iter 1357, Loss_f: 4.14713e-02
# Iter 1358, Loss_f: 4.14520e-02
# Iter 1359, Loss_f: 4.14282e-02
# Iter 1360, Loss_f: 4.14021e-02
# Iter 1361, Loss_f: 4.13799e-02
# Iter 1362, Loss_f: 4.13665e-02
# Iter 1363, Loss_f: 4.13446e-02
# Iter 1364, Loss_f: 4.13345e-02
# Iter 1365, Loss_f: 4.13234e-02
# Iter 1366, Loss_f: 4.13178e-02
# Iter 1367, Loss_f: 4.13143e-02
# Iter 1368, Loss_f: 4.13090e-02
# Iter 1369, Loss_f: 4.13047e-02
# Iter 1370, Loss_f: 4.12968e-02
# Iter 1371, Loss_f: 4.12968e-02
# Iter 1372, Loss_f: 4.12878e-02
# Iter 1373, Loss_f: 4.12766e-02
# Iter 1374, Loss_f: 4.12688e-02
# Iter 1375, Loss_f: 4.12627e-02
# Iter 1376, Loss_f: 4.13673e-02
# Iter 1377, Loss_f: 4.12590e-02
# Iter 1378, Loss_f: 4.12500e-02
# Iter 1379, Loss_f: 4.12396e-02
# Iter 1380, Loss_f: 4.12357e-02
# Iter 1381, Loss_f: 4.12292e-02
# Iter 1382, Loss_f: 4.12238e-02
# Iter 1383, Loss_f: 4.12174e-02
# Iter 1384, Loss_f: 4.12132e-02
# Iter 1385, Loss_f: 4.12065e-02
# Iter 1386, Loss_f: 4.11985e-02
# Iter 1387, Loss_f: 4.11927e-02
# Iter 1388, Loss_f: 4.11872e-02
# Iter 1389, Loss_f: 4.11817e-02
# Iter 1390, Loss_f: 4.11758e-02
# Iter 1391, Loss_f: 4.11758e-02
# Iter 1392, Loss_f: 4.11555e-02
# Iter 1393, Loss_f: 4.15454e-02
# Iter 1394, Loss_f: 4.11529e-02
# Iter 1395, Loss_f: 4.14363e-02
# Iter 1396, Loss_f: 4.11482e-02
# Iter 1397, Loss_f: 4.11194e-02
# Iter 1398, Loss_f: 4.10720e-02
# Iter 1399, Loss_f: 4.10264e-02
# Iter 1400, Loss_f: 4.09757e-02
# Iter 1401, Loss_f: 4.09490e-02
# Iter 1402, Loss_f: 4.09512e-02
# Iter 1403, Loss_f: 4.09214e-02
# Iter 1404, Loss_f: 4.09048e-02
# Iter 1405, Loss_f: 4.09113e-02
# Iter 1406, Loss_f: 4.08934e-02
# Iter 1407, Loss_f: 4.09447e-02
# Iter 1408, Loss_f: 4.08830e-02
# Iter 1409, Loss_f: 4.54837e-02
# Iter 1410, Loss_f: 4.08811e-02
# Iter 1411, Loss_f: 4.08811e-02
# Iter 1412, Loss_f: 4.08521e-02
# Iter 1413, Loss_f: 4.07396e-02
# Iter 1414, Loss_f: 4.13412e-02
# Iter 1415, Loss_f: 4.06818e-02
# Iter 1416, Loss_f: 4.05777e-02
# Iter 1417, Loss_f: 4.05171e-02
# Iter 1418, Loss_f: 4.04521e-02
# Iter 1419, Loss_f: 4.03767e-02
# Iter 1420, Loss_f: 4.02467e-02
# Iter 1421, Loss_f: 4.01697e-02
# Iter 1422, Loss_f: 4.00852e-02
# Iter 1423, Loss_f: 4.02821e-02
# Iter 1424, Loss_f: 4.00503e-02
# Iter 1425, Loss_f: 3.99621e-02
# Iter 1426, Loss_f: 3.98807e-02
# Iter 1427, Loss_f: 3.98525e-02
# Iter 1428, Loss_f: 3.98020e-02
# Iter 1429, Loss_f: 3.96760e-02
# Iter 1430, Loss_f: 3.95429e-02
# Iter 1431, Loss_f: 3.95429e-02
# Iter 1432, Loss_f: 3.95895e-02
# Iter 1433, Loss_f: 3.94274e-02
# Iter 1434, Loss_f: 3.93594e-02
# Iter 1435, Loss_f: 4.67077e-02
# Iter 1436, Loss_f: 3.93416e-02
# Iter 1437, Loss_f: 3.92330e-02
# Iter 1438, Loss_f: 3.91409e-02
# Iter 1439, Loss_f: 3.89653e-02
# Iter 1440, Loss_f: 3.91986e-02
# Iter 1441, Loss_f: 3.88432e-02
# Iter 1442, Loss_f: 3.96860e-02
# Iter 1443, Loss_f: 3.88045e-02
# Iter 1444, Loss_f: 3.87399e-02
# Iter 1445, Loss_f: 3.86816e-02
# Iter 1446, Loss_f: 3.86425e-02
# Iter 1447, Loss_f: 3.86203e-02
# Iter 1448, Loss_f: 3.85288e-02
# Iter 1449, Loss_f: 3.83732e-02
# Iter 1450, Loss_f: 3.82572e-02
# Iter 1451, Loss_f: 3.82572e-02
# Iter 1452, Loss_f: 3.80897e-02
# Iter 1453, Loss_f: 3.80208e-02
# Iter 1454, Loss_f: 3.79999e-02
# Iter 1455, Loss_f: 3.79576e-02
# Iter 1456, Loss_f: 3.79982e-02
# Iter 1457, Loss_f: 3.79421e-02
# Iter 1458, Loss_f: 3.79234e-02
# Iter 1459, Loss_f: 3.79117e-02
# Iter 1460, Loss_f: 3.79048e-02
# Iter 1461, Loss_f: 3.79041e-02
# Iter 1462, Loss_f: 3.78986e-02
# Iter 1463, Loss_f: 3.78879e-02
# Iter 1464, Loss_f: 3.78754e-02
# Iter 1465, Loss_f: 3.78612e-02
# Iter 1466, Loss_f: 3.81311e-02
# Iter 1467, Loss_f: 3.78571e-02
# Iter 1468, Loss_f: 3.78406e-02
# Iter 1469, Loss_f: 3.79175e-02
# Iter 1470, Loss_f: 3.78367e-02
# Iter 1471, Loss_f: 3.78367e-02
# Iter 1472, Loss_f: 3.79129e-02
# Iter 1473, Loss_f: 3.78327e-02
# Iter 1474, Loss_f: 3.78190e-02
# Iter 1475, Loss_f: 3.78077e-02
# Iter 1476, Loss_f: 3.77995e-02
# Iter 1477, Loss_f: 3.77916e-02
# Iter 1478, Loss_f: 3.77845e-02
# Iter 1479, Loss_f: 3.77790e-02
# Iter 1480, Loss_f: 3.77740e-02
# Iter 1481, Loss_f: 3.77658e-02
# Iter 1482, Loss_f: 3.77598e-02
# Iter 1483, Loss_f: 3.81220e-02
# Iter 1484, Loss_f: 3.77579e-02
# Iter 1485, Loss_f: 3.77514e-02
# Iter 1486, Loss_f: 3.77470e-02
# Iter 1487, Loss_f: 3.77408e-02
# Iter 1488, Loss_f: 3.77331e-02
# Iter 1489, Loss_f: 3.77223e-02
# Iter 1490, Loss_f: 3.77112e-02
# Iter 1491, Loss_f: 3.77112e-02
# Iter 1492, Loss_f: 3.77133e-02
# Iter 1493, Loss_f: 3.77060e-02
# Iter 1494, Loss_f: 3.76956e-02
# Iter 1495, Loss_f: 3.76858e-02
# Iter 1496, Loss_f: 3.76777e-02
# Iter 1497, Loss_f: 3.76732e-02
# Iter 1498, Loss_f: 3.76669e-02
# Iter 1499, Loss_f: 3.76570e-02
# Iter 1500, Loss_f: 3.76526e-02
# Iter 1501, Loss_f: 3.76783e-02
# Iter 1502, Loss_f: 3.76455e-02
# Iter 1503, Loss_f: 3.76241e-02
# Iter 1504, Loss_f: 3.76050e-02
# Iter 1505, Loss_f: 3.75994e-02
# Iter 1506, Loss_f: 3.75887e-02
# Iter 1507, Loss_f: 3.75793e-02
# Iter 1508, Loss_f: 3.75742e-02
# Iter 1509, Loss_f: 3.75636e-02
# Iter 1510, Loss_f: 3.75558e-02
# Iter 1511, Loss_f: 3.75558e-02
# Iter 1512, Loss_f: 3.76017e-02
# Iter 1513, Loss_f: 3.75542e-02
# Iter 1514, Loss_f: 3.75469e-02
# Iter 1515, Loss_f: 3.75209e-02
# Iter 1516, Loss_f: 3.75146e-02
# Iter 1517, Loss_f: 3.75083e-02
# Iter 1518, Loss_f: 3.75045e-02
# Iter 1519, Loss_f: 3.75032e-02
# Iter 1520, Loss_f: 3.74980e-02
# Iter 1521, Loss_f: 3.74893e-02
# Iter 1522, Loss_f: 3.76268e-02
# Iter 1523, Loss_f: 3.74837e-02
# Iter 1524, Loss_f: 3.74669e-02
# Iter 1525, Loss_f: 3.74408e-02
# Iter 1526, Loss_f: 3.74025e-02
# Iter 1527, Loss_f: 3.73660e-02
# Iter 1528, Loss_f: 3.73459e-02
# Iter 1529, Loss_f: 3.72991e-02
# Iter 1530, Loss_f: 3.73143e-02
# Iter 1531, Loss_f: 3.72714e-02
# Iter 1532, Loss_f: 3.72714e-02
# Iter 1533, Loss_f: 3.72497e-02
# Iter 1534, Loss_f: 3.72245e-02
# Iter 1535, Loss_f: 3.72100e-02
# Iter 1536, Loss_f: 3.71952e-02
# Iter 1537, Loss_f: 3.71702e-02
# Iter 1538, Loss_f: 3.71643e-02
# Iter 1539, Loss_f: 3.71430e-02
# Iter 1540, Loss_f: 3.71222e-02
# Iter 1541, Loss_f: 3.70870e-02
# Iter 1542, Loss_f: 4.10860e-02
# Iter 1543, Loss_f: 3.70829e-02
# Iter 1544, Loss_f: 3.70761e-02
# Iter 1545, Loss_f: 3.70322e-02
# Iter 1546, Loss_f: 3.69873e-02
# Iter 1547, Loss_f: 3.69348e-02
# Iter 1548, Loss_f: 3.69565e-02
# Iter 1549, Loss_f: 3.69009e-02
# Iter 1550, Loss_f: 3.68502e-02
# Iter 1551, Loss_f: 3.67928e-02
# Iter 1552, Loss_f: 3.67928e-02
# Iter 1553, Loss_f: 3.67262e-02
# Iter 1554, Loss_f: 3.70946e-02
# Iter 1555, Loss_f: 3.66967e-02
# Iter 1556, Loss_f: 3.66282e-02
# Iter 1557, Loss_f: 3.64863e-02
# Iter 1558, Loss_f: 3.67258e-02
# Iter 1559, Loss_f: 3.64158e-02
# Iter 1560, Loss_f: 3.62749e-02
# Iter 1561, Loss_f: 3.65030e-02
# Iter 1562, Loss_f: 3.62058e-02
# Iter 1563, Loss_f: 3.63267e-02
# Iter 1564, Loss_f: 3.61538e-02
# Iter 1565, Loss_f: 3.60682e-02
# Iter 1566, Loss_f: 3.60014e-02
# Iter 1567, Loss_f: 3.59232e-02
# Iter 1568, Loss_f: 3.57899e-02
# Iter 1569, Loss_f: 4.49516e-02
# Iter 1570, Loss_f: 3.57725e-02
# Iter 1571, Loss_f: 3.56599e-02
# Iter 1572, Loss_f: 3.56599e-02
# Iter 1573, Loss_f: 3.57405e-02
# Iter 1574, Loss_f: 3.56177e-02
# Iter 1575, Loss_f: 3.55502e-02
# Iter 1576, Loss_f: 3.55002e-02
# Iter 1577, Loss_f: 3.54448e-02
# Iter 1578, Loss_f: 3.54133e-02
# Iter 1579, Loss_f: 3.53689e-02
# Iter 1580, Loss_f: 3.53336e-02
# Iter 1581, Loss_f: 3.55775e-02
# Iter 1582, Loss_f: 3.53185e-02
# Iter 1583, Loss_f: 3.58657e-02
# Iter 1584, Loss_f: 3.51901e-02
# ...
# Iter 3699, Loss_f: 3.26178e-02
# Iter 3700, Loss_f: 3.26178e-02
# Iter 3701, Loss_f: 3.26936e-02
# Iter 3702, Loss_f: 3.26180e-02
# Iter 3703, Loss_f: 3.26185e-02
# Iter 3704, Loss_f: 3.26180e-02
# Iter 3705, Loss_f: 3.26185e-02
# Iter 3706, Loss_f: 3.26178e-02
# Iter 3707, Loss_f: 3.26178e-02
# Iter 3708, Loss_f: 3.26178e-02
# Iter 3709, Loss_f: 3.26936e-02
# Iter 3710, Loss_f: 3.26180e-02
# Iter 3711, Loss_f: 3.26185e-02
# Iter 3712, Loss_f: 3.26180e-02
# Iter 3713, Loss_f: 3.26185e-02
# Iter 3714, Loss_f: 3.26178e-02
# Iter 3715, Loss_f: 3.26178e-02
# Iter 3716, Loss_f: 3.26178e-02
# Iter 3717, Loss_f: 3.26936e-02
# Iter 3718, Loss_f: 3.26180e-02
# Iter 3719, Loss_f: 3.26185e-02
# Iter 3720, Loss_f: 3.26180e-02
# Iter 3721, Loss_f: 3.26185e-02
# Iter 3722, Loss_f: 3.26178e-02
# Iter 3723, Loss_f: 3.26178e-02
# Iter 3724, Loss_f: 3.26178e-02
# Iter 3725, Loss_f: 3.26936e-02
# Iter 3726, Loss_f: 3.26180e-02
# Iter 3727, Loss_f: 3.26185e-02
# Iter 3728, Loss_f: 3.26180e-02
# Iter 3729, Loss_f: 3.26185e-02
# Iter 3730, Loss_f: 3.26178e-02
# Iter 3731, Loss_f: 3.26178e-02
# Iter 3732, Loss_f: 3.26178e-02
# Iter 3733, Loss_f: 3.26936e-02
# Iter 3734, Loss_f: 3.26180e-02
# Iter 3735, Loss_f: 3.26185e-02
# Iter 3736, Loss_f: 3.26180e-02
# Iter 3737, Loss_f: 3.26185e-02
# Iter 3738, Loss_f: 3.26178e-02
# Iter 3739, Loss_f: 3.26178e-02
# Iter 3740, Loss_f: 3.26178e-02
# Iter 3741, Loss_f: 3.26936e-02
# Iter 3742, Loss_f: 3.26180e-02
# Iter 3743, Loss_f: 3.26185e-02
# Iter 3744, Loss_f: 3.26180e-02
# Iter 3745, Loss_f: 3.26185e-02
# Iter 3746, Loss_f: 3.26178e-02
# Iter 3747, Loss_f: 3.26178e-02
# Iter 3748, Loss_f: 3.26178e-02
# Iter 3749, Loss_f: 3.26936e-02
# Iter 3750, Loss_f: 3.26180e-02
# Iter 3751, Loss_f: 3.26185e-02
# Iter 3752, Loss_f: 3.26180e-02
# Iter 3753, Loss_f: 3.26185e-02
# Iter 3754, Loss_f: 3.26178e-02
# Iter 3755, Loss_f: 3.26178e-02
# Iter 3756, Loss_f: 3.26178e-02
# Iter 3757, Loss_f: 3.26936e-02
# Iter 3758, Loss_f: 3.26180e-02
# Iter 3759, Loss_f: 3.26185e-02
# Iter 3760, Loss_f: 3.26180e-02
# Iter 3761, Loss_f: 3.26185e-02
# Iter 3762, Loss_f: 3.26178e-02
# Iter 3763, Loss_f: 3.26178e-02
# Iter 3764, Loss_f: 3.26178e-02
# Iter 3765, Loss_f: 3.26936e-02
# Iter 3766, Loss_f: 3.26180e-02
# Iter 3767, Loss_f: 3.26185e-02
# Iter 3768, Loss_f: 3.26180e-02
# Iter 3769, Loss_f: 3.26185e-02
# Iter 3770, Loss_f: 3.26178e-02
# Iter 3771, Loss_f: 3.26178e-02
# Iter 3772, Loss_f: 3.26178e-02
# Iter 3773, Loss_f: 3.26936e-02
# Iter 3774, Loss_f: 3.26180e-02
# Iter 3775, Loss_f: 3.26185e-02
# Iter 3776, Loss_f: 3.26180e-02
# Iter 3777, Loss_f: 3.26185e-02
# Iter 3778, Loss_f: 3.26178e-02
# Iter 3779, Loss_f: 3.26178e-02
# Iter 3780, Loss_f: 3.26178e-02
# Iter 3781, Loss_f: 3.26936e-02
# Iter 3782, Loss_f: 3.26180e-02
# Iter 3783, Loss_f: 3.26185e-02
# Iter 3784, Loss_f: 3.26180e-02
# Iter 3785, Loss_f: 3.26185e-02
# Iter 3786, Loss_f: 3.26178e-02
# Iter 3787, Loss_f: 3.26178e-02
# Iter 3788, Loss_f: 3.26178e-02
# Iter 3789, Loss_f: 3.26936e-02
# Iter 3790, Loss_f: 3.26180e-02
# Iter 3791, Loss_f: 3.26185e-02
# Iter 3792, Loss_f: 3.26180e-02
# Iter 3793, Loss_f: 3.26185e-02
# Iter 3794, Loss_f: 3.26178e-02
# Iter 3795, Loss_f: 3.26178e-02
# Iter 3796, Loss_f: 3.26178e-02
# Iter 3797, Loss_f: 3.26936e-02
# Iter 3798, Loss_f: 3.26180e-02
# Iter 3799, Loss_f: 3.26185e-02
# Iter 3800, Loss_f: 3.26180e-02
# Iter 3801, Loss_f: 3.26185e-02
# Iter 3802, Loss_f: 3.26178e-02
# Iter 3803, Loss_f: 3.26178e-02
# Iter 3804, Loss_f: 3.26178e-02
# Iter 3805, Loss_f: 3.26936e-02
# Iter 3806, Loss_f: 3.26180e-02
# Iter 3807, Loss_f: 3.26185e-02
# Iter 3808, Loss_f: 3.26180e-02
# Iter 3809, Loss_f: 3.26185e-02
# Iter 3810, Loss_f: 3.26178e-02
# Iter 3811, Loss_f: 3.26178e-02
# Iter 3812, Loss_f: 3.26178e-02
# Iter 3813, Loss_f: 3.26936e-02
# Iter 3814, Loss_f: 3.26180e-02
# Iter 3815, Loss_f: 3.26185e-02
# Iter 3816, Loss_f: 3.26180e-02
# Iter 3817, Loss_f: 3.26185e-02
# Iter 3818, Loss_f: 3.26178e-02
# Iter 3819, Loss_f: 3.26178e-02
# Iter 3820, Loss_f: 3.26178e-02
# Iter 3821, Loss_f: 3.26936e-02
# Iter 3822, Loss_f: 3.26180e-02
# Iter 3823, Loss_f: 3.26185e-02
# Iter 3824, Loss_f: 3.26180e-02
# Iter 3825, Loss_f: 3.26185e-02
# Iter 3826, Loss_f: 3.26178e-02
# Iter 3827, Loss_f: 3.26178e-02
# Iter 3828, Loss_f: 3.26178e-02
# Iter 3829, Loss_f: 3.26936e-02
# Iter 3830, Loss_f: 3.26180e-02
# Iter 3831, Loss_f: 3.26185e-02
# Iter 3832, Loss_f: 3.26180e-02
# Iter 3833, Loss_f: 3.26185e-02
# Iter 3834, Loss_f: 3.26178e-02
# Iter 3835, Loss_f: 3.26178e-02
# Iter 3836, Loss_f: 3.26178e-02
# Iter 3837, Loss_f: 3.26936e-02
# Iter 3838, Loss_f: 3.26180e-02
# Iter 3839, Loss_f: 3.26185e-02
# Iter 3840, Loss_f: 3.26180e-02
# Iter 3841, Loss_f: 3.26185e-02
# Iter 3842, Loss_f: 3.26178e-02
# Iter 3843, Loss_f: 3.26178e-02
# Iter 3844, Loss_f: 3.26178e-02
# Iter 3845, Loss_f: 3.26936e-02
# Iter 3846, Loss_f: 3.26180e-02
# Iter 3847, Loss_f: 3.26185e-02
# Iter 3848, Loss_f: 3.26180e-02
# Iter 3849, Loss_f: 3.26185e-02
# Iter 3850, Loss_f: 3.26178e-02
# Iter 3851, Loss_f: 3.26178e-02
# Iter 3852, Loss_f: 3.26178e-02
# Iter 3853, Loss_f: 3.26936e-02
# Iter 3854, Loss_f: 3.26180e-02
# Iter 3855, Loss_f: 3.26185e-02
# Iter 3856, Loss_f: 3.26180e-02
# Iter 3857, Loss_f: 3.26185e-02
# Iter 3858, Loss_f: 3.26178e-02
# Iter 3859, Loss_f: 3.26178e-02
# Iter 3860, Loss_f: 3.26178e-02
# Iter 3861, Loss_f: 3.26936e-02
# Iter 3862, Loss_f: 3.26180e-02
# Iter 3863, Loss_f: 3.26185e-02
# Iter 3864, Loss_f: 3.26180e-02
# Iter 3865, Loss_f: 3.26185e-02
# Iter 3866, Loss_f: 3.26178e-02
# Iter 3867, Loss_f: 3.26178e-02
# Iter 3868, Loss_f: 3.26178e-02
# Iter 3869, Loss_f: 3.26936e-02
# Iter 3870, Loss_f: 3.26180e-02
# Iter 3871, Loss_f: 3.26185e-02
# Iter 3872, Loss_f: 3.26180e-02
# Iter 3873, Loss_f: 3.26185e-02
# Iter 3874, Loss_f: 3.26178e-02
# Iter 3875, Loss_f: 3.26178e-02
# Iter 3876, Loss_f: 3.26178e-02
# Iter 3877, Loss_f: 3.26936e-02
# Iter 3878, Loss_f: 3.26180e-02
# Iter 3879, Loss_f: 3.26185e-02
# Iter 3880, Loss_f: 3.26180e-02
# Iter 3881, Loss_f: 3.26185e-02
# Iter 3882, Loss_f: 3.26178e-02
# Iter 3883, Loss_f: 3.26178e-02
# Iter 3884, Loss_f: 3.26178e-02
# Iter 3885, Loss_f: 3.26936e-02
# Iter 3886, Loss_f: 3.26180e-02
# Iter 3887, Loss_f: 3.26185e-02
# Iter 3888, Loss_f: 3.26180e-02
# Iter 3889, Loss_f: 3.26185e-02
# Iter 3890, Loss_f: 3.26178e-02
# Iter 3891, Loss_f: 3.26178e-02
# Iter 3892, Loss_f: 3.26178e-02
# Iter 3893, Loss_f: 3.26936e-02
# Iter 3894, Loss_f: 3.26180e-02
# Iter 3895, Loss_f: 3.26185e-02
# Iter 3896, Loss_f: 3.26180e-02
# Iter 3897, Loss_f: 3.26185e-02
# Iter 3898, Loss_f: 3.26178e-02
# Iter 3899, Loss_f: 3.26178e-02
# Iter 3900, Loss_f: 3.26178e-02
# Iter 3901, Loss_f: 3.26936e-02
# Iter 3902, Loss_f: 3.26180e-02
# Iter 3903, Loss_f: 3.26185e-02
# Iter 3904, Loss_f: 3.26180e-02
# Iter 3905, Loss_f: 3.26185e-02
# Iter 3906, Loss_f: 3.26178e-02
# Iter 3907, Loss_f: 3.26178e-02
# Iter 3908, Loss_f: 3.26178e-02
# Iter 3909, Loss_f: 3.26936e-02
# Iter 3910, Loss_f: 3.26180e-02
# Iter 3911, Loss_f: 3.26185e-02
# Iter 3912, Loss_f: 3.26180e-02
# Iter 3913, Loss_f: 3.26185e-02
# Iter 3914, Loss_f: 3.26178e-02
# Iter 3915, Loss_f: 3.26178e-02
# Iter 3916, Loss_f: 3.26178e-02
# Iter 3917, Loss_f: 3.26936e-02
# Iter 3918, Loss_f: 3.26180e-02
# Iter 3919, Loss_f: 3.26185e-02
# Iter 3920, Loss_f: 3.26180e-02
# Iter 3921, Loss_f: 3.26185e-02
# Iter 3922, Loss_f: 3.26178e-02
# Iter 3923, Loss_f: 3.26178e-02
# Iter 3924, Loss_f: 3.26178e-02
# Iter 3925, Loss_f: 3.26936e-02
# Iter 3926, Loss_f: 3.26180e-02
# Iter 3927, Loss_f: 3.26185e-02
# Iter 3928, Loss_f: 3.26180e-02
# Iter 3929, Loss_f: 3.26185e-02
# Iter 3930, Loss_f: 3.26178e-02
# Iter 3931, Loss_f: 3.26178e-02
# Iter 3932, Loss_f: 3.26178e-02
# Iter 3933, Loss_f: 3.26936e-02
# Iter 3934, Loss_f: 3.26180e-02
# Iter 3935, Loss_f: 3.26185e-02
# Iter 3936, Loss_f: 3.26180e-02
# Iter 3937, Loss_f: 3.26185e-02
# Iter 3938, Loss_f: 3.26178e-02
# Iter 3939, Loss_f: 3.26178e-02
# Iter 3940, Loss_f: 3.26178e-02
# Iter 3941, Loss_f: 3.26936e-02
# Iter 3942, Loss_f: 3.26180e-02
# Iter 3943, Loss_f: 3.26185e-02
# Iter 3944, Loss_f: 3.26180e-02
# Iter 3945, Loss_f: 3.26185e-02
# Iter 3946, Loss_f: 3.26178e-02
# Iter 3947, Loss_f: 3.26178e-02
# Iter 3948, Loss_f: 3.26178e-02
# Iter 3949, Loss_f: 3.26936e-02
# Iter 3950, Loss_f: 3.26180e-02
# Iter 3951, Loss_f: 3.26185e-02
# Iter 3952, Loss_f: 3.26180e-02
# Iter 3953, Loss_f: 3.26185e-02
# Iter 3954, Loss_f: 3.26178e-02
# Iter 3955, Loss_f: 3.26178e-02
# Iter 3956, Loss_f: 3.26178e-02
# Iter 3957, Loss_f: 3.26936e-02
# Iter 3958, Loss_f: 3.26180e-02
# Iter 3959, Loss_f: 3.26185e-02
# Iter 3960, Loss_f: 3.26180e-02
# Iter 3961, Loss_f: 3.26185e-02
# Iter 3962, Loss_f: 3.26178e-02
# Iter 3963, Loss_f: 3.26178e-02
# Iter 3964, Loss_f: 3.26178e-02
# Iter 3965, Loss_f: 3.26936e-02
# Iter 3966, Loss_f: 3.26180e-02
# Iter 3967, Loss_f: 3.26185e-02
# Iter 3968, Loss_f: 3.26180e-02
# Iter 3969, Loss_f: 3.26185e-02
# Iter 3970, Loss_f: 3.26178e-02
# Iter 3971, Loss_f: 3.26178e-02
# Iter 3972, Loss_f: 3.26178e-02
# Iter 3973, Loss_f: 3.26936e-02
# Iter 3974, Loss_f: 3.26180e-02
# Iter 3975, Loss_f: 3.26185e-02
# Iter 3976, Loss_f: 3.26180e-02
# Iter 3977, Loss_f: 3.26185e-02
# Iter 3978, Loss_f: 3.26178e-02
# Iter 3979, Loss_f: 3.26178e-02
# Iter 3980, Loss_f: 3.26178e-02
# Iter 3981, Loss_f: 3.26936e-02
# Iter 3982, Loss_f: 3.26180e-02
# Iter 3983, Loss_f: 3.26185e-02
# Iter 3984, Loss_f: 3.26180e-02
# Iter 3985, Loss_f: 3.26185e-02
# Iter 3986, Loss_f: 3.26178e-02
# Iter 3987, Loss_f: 3.26178e-02
# Iter 3988, Loss_f: 3.26178e-02
# Iter 3989, Loss_f: 3.26936e-02
# Iter 3990, Loss_f: 3.26180e-02
# Iter 3991, Loss_f: 3.26185e-02
# Iter 3992, Loss_f: 3.26180e-02
# Iter 3993, Loss_f: 3.26185e-02
# Iter 3994, Loss_f: 3.26178e-02
# Iter 3995, Loss_f: 3.26178e-02
# Iter 3996, Loss_f: 3.26178e-02
# Iter 3997, Loss_f: 3.26936e-02
# Iter 3998, Loss_f: 3.26180e-02
# Iter 3999, Loss_f: 3.26185e-02
# Iter 4000, Loss_f: 3.26180e-02
# Iter 4001, Loss_f: 3.26185e-02
# Iter 4002, Loss_f: 3.26178e-02
# Iter 4003, Loss_f: 3.26178e-02
# Iter 4004, Loss_f: 3.26178e-02
# Iter 4005, Loss_f: 3.26936e-02
# Iter 4006, Loss_f: 3.26180e-02
# Iter 4007, Loss_f: 3.26185e-02
# Iter 4008, Loss_f: 3.26180e-02
# Iter 4009, Loss_f: 3.26185e-02
# Iter 4010, Loss_f: 3.26178e-02
# Iter 4011, Loss_f: 3.26178e-02
# Iter 4012, Loss_f: 3.26178e-02
# Iter 4013, Loss_f: 3.26936e-02
# Iter 4014, Loss_f: 3.26180e-02
# Iter 4015, Loss_f: 3.26185e-02
# Iter 4016, Loss_f: 3.26180e-02
# Iter 4017, Loss_f: 3.26185e-02
# Iter 4018, Loss_f: 3.26178e-02
# Iter 4019, Loss_f: 3.26178e-02
# Iter 4020, Loss_f: 3.26178e-02
# Iter 4021, Loss_f: 3.26936e-02
# Iter 4022, Loss_f: 3.26180e-02
# Iter 4023, Loss_f: 3.26185e-02
# Iter 4024, Loss_f: 3.26180e-02
# Iter 4025, Loss_f: 3.26185e-02
# Iter 4026, Loss_f: 3.26178e-02
# Iter 4027, Loss_f: 3.26178e-02
# Iter 4028, Loss_f: 3.26178e-02
# Iter 4029, Loss_f: 3.26936e-02
# Iter 4030, Loss_f: 3.26180e-02
# Iter 4031, Loss_f: 3.26185e-02
# Iter 4032, Loss_f: 3.26180e-02
# Iter 4033, Loss_f: 3.26185e-02
# Iter 4034, Loss_f: 3.26178e-02
# Iter 4035, Loss_f: 3.26178e-02
# Iter 4036, Loss_f: 3.26178e-02
# Iter 4037, Loss_f: 3.26936e-02
# Iter 4038, Loss_f: 3.26180e-02
# Iter 4039, Loss_f: 3.26185e-02
# Iter 4040, Loss_f: 3.26180e-02
# Iter 4041, Loss_f: 3.26185e-02
# Iter 4042, Loss_f: 3.26178e-02
# Iter 4043, Loss_f: 3.26178e-02
# Iter 4044, Loss_f: 3.26178e-02
# Iter 4045, Loss_f: 3.26936e-02
# Iter 4046, Loss_f: 3.26180e-02
# Iter 4047, Loss_f: 3.26185e-02
# Iter 4048, Loss_f: 3.26180e-02
# Iter 4049, Loss_f: 3.26185e-02
# Iter 4050, Loss_f: 3.26178e-02
# Iter 4051, Loss_f: 3.26178e-02
# Iter 4052, Loss_f: 3.26178e-02
# Iter 4053, Loss_f: 3.26936e-02
# Iter 4054, Loss_f: 3.26180e-02
# Iter 4055, Loss_f: 3.26185e-02
# Iter 4056, Loss_f: 3.26180e-02
# Iter 4057, Loss_f: 3.26185e-02
# Iter 4058, Loss_f: 3.26178e-02
# Iter 4059, Loss_f: 3.26178e-02
# Iter 4060, Loss_f: 3.26178e-02
# Iter 4061, Loss_f: 3.26936e-02
# Iter 4062, Loss_f: 3.26180e-02
# Iter 4063, Loss_f: 3.26185e-02
# Iter 4064, Loss_f: 3.26180e-02
# Iter 4065, Loss_f: 3.26185e-02
# Iter 4066, Loss_f: 3.26178e-02
# Iter 4067, Loss_f: 3.26178e-02
# Iter 4068, Loss_f: 3.26178e-02
# Iter 4069, Loss_f: 3.26936e-02
# Iter 4070, Loss_f: 3.26180e-02
# Iter 4071, Loss_f: 3.26185e-02
# Iter 4072, Loss_f: 3.26180e-02
# Iter 4073, Loss_f: 3.26185e-02
# Iter 4074, Loss_f: 3.26178e-02
# Iter 4075, Loss_f: 3.26178e-02
# Iter 4076, Loss_f: 3.26178e-02
# Iter 4077, Loss_f: 3.26936e-02
# Iter 4078, Loss_f: 3.26180e-02
# Iter 4079, Loss_f: 3.26185e-02
# Iter 4080, Loss_f: 3.26180e-02
# Iter 4081, Loss_f: 3.26185e-02
# Iter 4082, Loss_f: 3.26178e-02
# Iter 4083, Loss_f: 3.26178e-02
# Iter 4084, Loss_f: 3.26178e-02
# Iter 4085, Loss_f: 3.26936e-02
# Iter 4086, Loss_f: 3.26180e-02
# Iter 4087, Loss_f: 3.26185e-02
# Iter 4088, Loss_f: 3.26180e-02
# Iter 4089, Loss_f: 3.26185e-02
# Iter 4090, Loss_f: 3.26178e-02
# Iter 4091, Loss_f: 3.26178e-02
# Iter 4092, Loss_f: 3.26178e-02
# Iter 4093, Loss_f: 3.26936e-02
# Iter 4094, Loss_f: 3.26180e-02
# Iter 4095, Loss_f: 3.26185e-02
# Iter 4096, Loss_f: 3.26180e-02
# Iter 4097, Loss_f: 3.26185e-02
# Iter 4098, Loss_f: 3.26178e-02
# Iter 4099, Loss_f: 3.26178e-02
# Iter 4100, Loss_f: 3.26178e-02
# Iter 4101, Loss_f: 3.26936e-02
# Iter 4102, Loss_f: 3.26180e-02
# Iter 4103, Loss_f: 3.26185e-02
# Iter 4104, Loss_f: 3.26180e-02
# Iter 4105, Loss_f: 3.26185e-02
# Iter 4106, Loss_f: 3.26178e-02
# Iter 4107, Loss_f: 3.26178e-02
# Iter 4108, Loss_f: 3.26178e-02
# Iter 4109, Loss_f: 3.26936e-02
# Iter 4110, Loss_f: 3.26180e-02
# Iter 4111, Loss_f: 3.26185e-02
# Iter 4112, Loss_f: 3.26180e-02
# Iter 4113, Loss_f: 3.26185e-02
# Iter 4114, Loss_f: 3.26178e-02
# Iter 4115, Loss_f: 3.26178e-02
# Iter 4116, Loss_f: 3.26178e-02
# Iter 4117, Loss_f: 3.26936e-02
# Iter 4118, Loss_f: 3.26180e-02
# Iter 4119, Loss_f: 3.26185e-02
# Iter 4120, Loss_f: 3.26180e-02
# Iter 4121, Loss_f: 3.26185e-02
# Iter 4122, Loss_f: 3.26178e-02
# Iter 4123, Loss_f: 3.26178e-02
# Iter 4124, Loss_f: 3.26178e-02
# Iter 4125, Loss_f: 3.26936e-02
# Iter 4126, Loss_f: 3.26180e-02
# Iter 4127, Loss_f: 3.26185e-02
# Iter 4128, Loss_f: 3.26180e-02
# Iter 4129, Loss_f: 3.26185e-02
# Iter 4130, Loss_f: 3.26178e-02
# Iter 4131, Loss_f: 3.26178e-02
# Iter 4132, Loss_f: 3.26178e-02
# Iter 4133, Loss_f: 3.26936e-02
# Iter 4134, Loss_f: 3.26180e-02
# Iter 4135, Loss_f: 3.26185e-02
# Iter 4136, Loss_f: 3.26180e-02
# Iter 4137, Loss_f: 3.26185e-02
# Iter 4138, Loss_f: 3.26178e-02
# Iter 4139, Loss_f: 3.26178e-02
# Iter 4140, Loss_f: 3.26178e-02
# Iter 4141, Loss_f: 3.26936e-02
# Iter 4142, Loss_f: 3.26180e-02
# Iter 4143, Loss_f: 3.26185e-02
# Iter 4144, Loss_f: 3.26180e-02
# Iter 4145, Loss_f: 3.26185e-02
# Iter 4146, Loss_f: 3.26178e-02
# Iter 4147, Loss_f: 3.26178e-02
# Iter 4148, Loss_f: 3.26178e-02
# Iter 4149, Loss_f: 3.26936e-02
# Iter 4150, Loss_f: 3.26180e-02
# Iter 4151, Loss_f: 3.26185e-02
# Iter 4152, Loss_f: 3.26180e-02
# Iter 4153, Loss_f: 3.26185e-02
# Iter 4154, Loss_f: 3.26178e-02
# Iter 4155, Loss_f: 3.26178e-02
# Iter 4156, Loss_f: 3.26178e-02
# Iter 4157, Loss_f: 3.26936e-02
# Iter 4158, Loss_f: 3.26180e-02
# Iter 4159, Loss_f: 3.26185e-02
# Iter 4160, Loss_f: 3.26180e-02
# Iter 4161, Loss_f: 3.26185e-02
# Iter 4162, Loss_f: 3.26178e-02
# Iter 4163, Loss_f: 3.26178e-02
# Iter 4164, Loss_f: 3.26178e-02
# Iter 4165, Loss_f: 3.26936e-02
# Iter 4166, Loss_f: 3.26180e-02
# Iter 4167, Loss_f: 3.26185e-02
# Iter 4168, Loss_f: 3.26180e-02
# Iter 4169, Loss_f: 3.26185e-02
# Iter 4170, Loss_f: 3.26178e-02
# Iter 4171, Loss_f: 3.26178e-02
# Iter 4172, Loss_f: 3.26178e-02
# Iter 4173, Loss_f: 3.26936e-02
# Iter 4174, Loss_f: 3.26180e-02
# Iter 4175, Loss_f: 3.26185e-02
# Iter 4176, Loss_f: 3.26180e-02
# Iter 4177, Loss_f: 3.26185e-02
# Iter 4178, Loss_f: 3.26178e-02
# Iter 4179, Loss_f: 3.26178e-02
# Iter 4180, Loss_f: 3.26178e-02
# Iter 4181, Loss_f: 3.26936e-02
# Iter 4182, Loss_f: 3.26180e-02
# Iter 4183, Loss_f: 3.26185e-02
# Iter 4184, Loss_f: 3.26180e-02
# Iter 4185, Loss_f: 3.26185e-02
# Iter 4186, Loss_f: 3.26178e-02
# Iter 4187, Loss_f: 3.26178e-02
# Iter 4188, Loss_f: 3.26178e-02
# Iter 4189, Loss_f: 3.26936e-02
# Iter 4190, Loss_f: 3.26180e-02
# Iter 4191, Loss_f: 3.26185e-02
# Iter 4192, Loss_f: 3.26180e-02
# Iter 4193, Loss_f: 3.26185e-02
# Iter 4194, Loss_f: 3.26178e-02
# Iter 4195, Loss_f: 3.26178e-02
# Iter 4196, Loss_f: 3.26178e-02
# Iter 4197, Loss_f: 3.26936e-02
# Iter 4198, Loss_f: 3.26180e-02
# Iter 4199, Loss_f: 3.26185e-02
# Iter 4200, Loss_f: 3.26180e-02
# Iter 4201, Loss_f: 3.26185e-02
# Iter 4202, Loss_f: 3.26178e-02
# Iter 4203, Loss_f: 3.26178e-02
# Iter 4204, Loss_f: 3.26178e-02
# Iter 4205, Loss_f: 3.26936e-02
# Iter 4206, Loss_f: 3.26180e-02
# Iter 4207, Loss_f: 3.26185e-02
# Iter 4208, Loss_f: 3.26180e-02
# Iter 4209, Loss_f: 3.26185e-02
# Iter 4210, Loss_f: 3.26178e-02
# Iter 4211, Loss_f: 3.26178e-02
# CPU times: user 1min 24s, sys: 1.25 s, total: 1min 25s
# Wall time: 1min 25s

# %%
u_pred, f_pred = model.predict(X_star)

error_u = np.linalg.norm(u_star-u_pred,2)/np.linalg.norm(u_star,2)
print('Error u: %e' % (error_u))                     

U_pred = griddata(X_star, u_pred.flatten(), (X, T), method='cubic')
Error = np.abs(Exact - U_pred)
# Out:
# Error u: 1.307954e-01

# %%
""" The aesthetic setting has changed. """

####### Row 0: u(t,x) ##################    

fig = plt.figure(figsize=(9, 5))
ax = fig.add_subplot(111)

h = ax.imshow(U_pred.T, interpolation='nearest', cmap='rainbow', 
              extent=[t.min(), t.max(), x.min(), x.max()], 
              origin='lower', aspect='auto')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.10)
cbar = fig.colorbar(h, cax=cax)
cbar.ax.tick_params(labelsize=15) 

ax.plot(
    X_u_train[:,1], 
    X_u_train[:,0], 
    'kx', label = 'Data (%d points)' % (u_train.shape[0]), 
    markersize = 4,  # marker size doubled
    clip_on = False,
    alpha=1.0
)

line = np.linspace(x.min(), x.max(), 2)[:,None]
ax.plot(t[25]*np.ones((2,1)), line, 'w-', linewidth = 1)
ax.plot(t[50]*np.ones((2,1)), line, 'w-', linewidth = 1)
ax.plot(t[75]*np.ones((2,1)), line, 'w-', linewidth = 1)

ax.set_xlabel('$t$', size=20)
ax.set_ylabel('$x$', size=20)
ax.legend(
    loc='upper center', 
    bbox_to_anchor=(0.9, -0.05), 
    ncol=5, 
    frameon=False, 
    prop={'size': 15}
)
ax.set_title('$u(t,x)$', fontsize = 20) # font size doubled
ax.tick_params(labelsize=15)

plt.show()

# %% [markdown]
# # **Visualizations**

# %%
####### Row 1: u(t,x) slices ################## 

""" The aesthetic setting has changed. """

fig = plt.figure(figsize=(14, 10))
ax = fig.add_subplot(111)

gs1 = gridspec.GridSpec(1, 3)
gs1.update(top=1-1.0/3.0-0.1, bottom=1.0-2.0/3.0, left=0.1, right=0.9, wspace=0.5)

ax = plt.subplot(gs1[0, 0])
ax.plot(x,Exact[25,:], 'b-', linewidth = 2, label = 'Exact')       
ax.plot(x,U_pred[25,:], 'r--', linewidth = 2, label = 'Prediction')
ax.set_xlabel('$x$')
ax.set_ylabel('$u(t,x)$')    
ax.set_title('$t = 0.25$', fontsize = 15)
ax.axis('square')
ax.set_xlim([-1.1,1.1])
ax.set_ylim([-1.1,1.1])

for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(15)

ax = plt.subplot(gs1[0, 1])
ax.plot(x,Exact[50,:], 'b-', linewidth = 2, label = 'Exact')       
ax.plot(x,U_pred[50,:], 'r--', linewidth = 2, label = 'Prediction')
ax.set_xlabel('$x$')
ax.set_ylabel('$u(t,x)$')
ax.axis('square')
ax.set_xlim([-1.1,1.1])
ax.set_ylim([-1.1,1.1])
ax.set_title('$t = 0.50$', fontsize = 15)
ax.legend(
    loc='upper center', 
    bbox_to_anchor=(0.5, -0.15), 
    ncol=5, 
    frameon=False, 
    prop={'size': 15}
)

for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(15)

ax = plt.subplot(gs1[0, 2])
ax.plot(x,Exact[75,:], 'b-', linewidth = 2, label = 'Exact')       
ax.plot(x,U_pred[75,:], 'r--', linewidth = 2, label = 'Prediction')
ax.set_xlabel('$x$')
ax.set_ylabel('$u(t,x)$')
ax.axis('square')
ax.set_xlim([-1.1,1.1])
ax.set_ylim([-1.1,1.1])    
ax.set_title('$t = 0.75$', fontsize = 15)

for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(15)

plt.show()

# %%
import matplotlib

x_axis = [i for i in range(1,len(train_error)+1)]

new_train_error = np.log(train_error)
plt.plot(x_axis, new_train_error)
# plt.ylim(1e-4, 1)
plt.title("train_error error")
# Out:
# Text(0.5, 1.0, 'train_error error')

# %%
x_col = model.x_f.detach().cpu().numpy()
t_col = model.t_f.detach().cpu().numpy()

plt.scatter(x_col, t_col)
plt.title("collocation points: {}- vanilla".format(N_f))
# Out:
# Text(0.5, 1.0, 'collocation points: 1000- vanilla')
